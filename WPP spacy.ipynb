# %%
import re
from datetime import datetime
import pandas as pd
import glob,os
import sys 
import zipfile
import numpy as np
import spacy

# %% [markdown]
# # Funciones

# %%
def path_recent_chat(Carpeta_path: str):
    """ Devuelve el df de la hoja especifica, del archivo mas reciente modificado de la carpeta especificada"""
    Path_n= Carpeta_path + '/*'
    tipo_de_archivo = '*.txt'
    # Busca el archivo más reciente
    archivos = glob.glob(Path_n + tipo_de_archivo)
    archivo_mas_reciente = max(archivos, key=os.path.getmtime)
    nombre_del_archivo_N = os.path.basename(archivo_mas_reciente)
    print(archivo_mas_reciente)
    return archivo_mas_reciente

def split_chat_messages(raw_text): 
    ''' funcion que splitea mensajes individuales de acuerdo al formate (iphone/android)'''
    # Verificar si es formato iPhone (comienza con corchetes)
    raw_text = raw_text.replace('\u200e', '').replace('\u202f', ' ').replace('\u00a0', ' ')

    iphone_format= False
    if re.search(r'\[\d{1,2}/\d{1,2}/\d{2}, \d{1,2}:\d{2}:\d{2} p\. m\.\]', raw_text):
        print('match iphone')
        # Formato iPhone
        processed_text = raw_text.replace('[', '\n[', 1).replace('\n[', '[', 1)
        iphone_format = True
        return re.split(r'\n(?=\[)', processed_text.strip()),iphone_format
    else:
        # Formato Android
        print('match android')
        android_pattern = r'\n(?=\d{1,2}/\d{1,2}/\d{4}, \d{1,2}:\d{2} - )'
        iphone_format = False
        return re.split(android_pattern, raw_text.strip()),iphone_format    
def parse_chat_line(line, format_flag=None):
    '''Función que separa cada mensaje individual en 3 grupos (timestamp, sender, message)'''
    # Eliminar caracteres especiales y espacios no deseados
    clean_line = line.replace('\u200e', '').replace('\u202f', ' ').replace('\u00a0', ' ').strip()
    
    if not clean_line:
        return None
    
    # Patrones para ambos formatos
    pattern_iphone = r'\[(\d{1,2}/\d{1,2}/\d{2,4}),\s*(\d{1,2}:\d{2}:\d{2}\s*(?:a\. m\.|p\. m\.))\]\s*(.*?):\s+(.+)'
    pattern_android = r'(\d{1,2}/\d{1,2}/\d{2,4},\s*\d{1,2}:\d{2})\s*-\s*(.*?):\s*(.*)'
    
    # Patrón para mensajes del sistema (sin remitente)
    pattern_system = r'(\d{1,2}/\d{1,2}/\d{2,4},\s*\d{1,2}:\d{2})\s*-\s*(.*)'

    # Intentar con iPhone primero
    match = re.match(pattern_iphone, clean_line,flags=re.DOTALL)
    if match:
        date_str, time_str, sender, message = match.groups()
        # Unificar fecha y hora en objeto datetime
        dt_str = f"{date_str} {time_str}".replace("a. m.", "AM").replace("p. m.", "PM")
        return (dt_str, sender, message)
    
    # Intentar con Android (incluyendo mensajes vacíos)
    match = re.match(pattern_android, clean_line,flags=re.DOTALL)
    if match:
        timestamp, sender, message = match.groups()
        # Si el mensaje está vacío, asignar cadena vacía explícitamente
        if message is None:
            message = ""
        return (timestamp, sender, message)
    
    # Intentar con mensajes del sistema (sin remitente)
    match = re.match(pattern_system, clean_line,flags=re.DOTALL)
    if match:
        timestamp, message = match.groups()
        return (timestamp, "Sistema", message)
    
    # Si coincide con el patron formateado:
    
    return None

def extraer_linea_completa(df):
    # Usamos una lista de comprensión con regex por fila (más eficiente que apply)
    resultados = []
    for valor, texto in zip(df['codigos_inc'], df['message_first']):
        patron = re.compile(rf"^.*{re.escape(valor)}.*$", re.MULTILINE)
        coincidencia = patron.search(texto)
        resultados.append(coincidencia.group(0).strip() if coincidencia else None)
    return resultados

def extraer_bloque_por_inc(df):
    resultados = []
    for valor, texto in zip(df['codigos_inc'], df['message']):
        if pd.isna(valor) or pd.isna(texto):
            resultados.append(None)
            continue
        valor_escapado = re.escape(valor)
        # Buscar la posición del código INC específico
        inc_match = re.search(valor_escapado, texto)
        if not inc_match:
            resultados.append(None)
            continue  
        inc_pos = inc_match.start()
        texto_despues_inc = texto[inc_pos:]
        
        # Encontrar todas las ocurrencias de HI después de este INC
        hi_ocurrencias = list(re.finditer(r'\bHI\b', texto_despues_inc, re.IGNORECASE))
        
        if len(hi_ocurrencias) >= 2:
            # Cortar hasta la segunda HI
            segunda_hi_pos = hi_ocurrencias[1].start()
            bloque_final = texto_despues_inc[:segunda_hi_pos].strip()
        else:
            # Si no hay segunda HI, tomar TODO el texto desde el INC actual
            bloque_final = texto_despues_inc.strip()
        
        # Limpiar tabs y espacios extras
        bloque_final = re.sub(r'\t', ' ', bloque_final)
        bloque_final = re.sub(r'\n{3,}', '\n\n', bloque_final)
        
        resultados.append(bloque_final)
            
    return resultados

# %%
if len(sys.argv) > 1: ## Ruta que le pasa el watchdog
    ruta_archv = sys.argv[1]
else:
    print('No se paso ruta de archivo.')

# %%
#ruta_archv = r'D:\DATA\wpp\Chat de WhatsApp con Averias Norte-VOC-CICSA.zip'
#ruta_archv = r'D:\DATA\wpp\test_format.zip'

# %%
with zipfile.ZipFile(ruta_archv, 'r') as zipf:
    # Listar todos los archivos
    print("Archivos en el ZIP:")
    for file_info in zipf.infolist():
        print(f"Nombre: {file_info.filename}")
        print(f"Tamaño: {file_info.file_size} bytes")
        print(f"Comprimido: {file_info.compress_size} bytes")
        print("---")
    
    # Leer contenido de un archivo específico
    with zipf.open(zipf.filelist[0].filename) as file:
        raw_text = file.read().decode('utf-8')
# Out:
# Archivos en el ZIP:
# Nombre: Chat de WhatsApp con Averias Norte-VOC-CICSA.txt
# Tamaño: 1030317 bytes
# Comprimido: 91001 bytes
# ---

# %%
# Leer todo el archivo como un solo string
data = []

# Limpiar caracteres invisibles
raw_text = raw_text.replace('\u200e', '').replace('\u202f', ' ').replace('\u00a0', ' ')

# Añadir marcador para luego reponer los corchetes
#raw_text = raw_text.replace('[', '\n[', 1).replace('\n[', '[', 1)  # Evita dividir antes del primer mensaje
messages,format_flag = split_chat_messages(raw_text)  # Split en cada línea que empieza con [

print(f"Total mensajes detectados: {len(messages)}")
# Out:
# match android
# Total mensajes detectados: 4738

# %%
# ruta_archv = path_recent_chat(r'D:\DATA\wpp')
#with open(ruta_archv, "r", encoding="utf-8") as file:
#     raw_text = file.read()

# %%
list_msg_split = [] ## el flags indica que formato estoy afrontando
if not format_flag:
    messages = messages[1:]
else:
    pass
for msg in messages:
    result = parse_chat_line(msg)
    if result:
        list_msg_split.append(result)
    else:
        # Manejar líneas que no coinciden con ningún patrón
        list_msg_split.append(("Desconocido", "Desconocido", msg))

# Convertir a DataFrame de pandas
df = pd.DataFrame(list_msg_split, columns=['timestamp', 'sender', 'message'])
df.head()
# Out:
#           timestamp           sender               message
# 0  21/7/2025, 09:21  +51 914 684 619
# 1  21/7/2025, 09:21  +51 914 684 619  <Multimedia omitido>
# 2  21/7/2025, 09:21  +51 914 684 619  <Multimedia omitido>
# 3  21/7/2025, 09:21  +51 914 684 619  <Multimedia omitido>
# 4  21/7/2025, 09:22  +51 914 089 629  <Multimedia omitido>

# %%
format_flag
# Out:
# False

# %%
if not format_flag: 
    df.timestamp = pd.to_datetime(df.timestamp,format = '%d/%m/%Y, %H:%M')
   
else: 
    df.timestamp = df.timestamp.replace("a. m.", "AM").replace("p. m.", "PM")
    df.timestamp = pd.to_datetime(df.timestamp,format = "%d/%m/%y %I:%M:%S %p")

# %% [markdown]
# ## df base

# %%
df.timestamp.describe()
# Out:
# count                             4737
# mean     2025-08-04 08:50:06.333122304
# min                2025-07-21 09:21:00
# 25%                2025-07-26 07:28:00
# 50%                2025-08-03 10:44:00
# 75%                2025-08-12 20:28:00
# max                2025-08-22 16:26:00
# Name: timestamp, dtype: object

# %%
### Filtro por solo mensajes de Incidencias

## solo mensajes que contengan numero de Incidendcias
df_inc = df[df.message.str.contains('INC',na=False)].copy()

### Separo el numero de incidencia para usarlo de indice 
df_inc['codigos_inc'] = df_inc['message'].str.findall(r'INC\d{9,}') # columna con codigo de incidencia
df_inc_e = df_inc.explode('codigos_inc').reset_index(drop=True)#Explando las duplicadas

# %%
if (df_inc_e[['sender','message']].any()).any():
    print(True)
# Out:
# True

# %%
### Solo incidencia Cerradas 
cerrado_df_C = df_inc_e[df_inc_e['message'].str.contains(r'CIERRE|CERRADO', na=False)].sort_values('timestamp').copy()
### Solo la ultima 
cerrado_df_unique = cerrado_df_C.sort_values('timestamp').drop_duplicates('codigos_inc',keep='last') ## me quedo con el ultimo

# %% [markdown]
# ## Encabezados robustos:

# %%
## bajo mi crieterio conviene sacar el encabezado del primer mensaje no del ultimo.
df_inc_e_F = df_inc_e.sort_values('timestamp').drop_duplicates('codigos_inc',keep='first') # primera aparicion
df_merged = pd.merge(cerrado_df_unique,
                     df_inc_e_F[['codigos_inc','message']].rename(columns={'message':'message_first'})
                     ,how='left',on='codigos_inc')

df_merged['Encabezado'] = extraer_linea_completa(df_merged).copy()

df_merged['Encabezado'] = df_merged['Encabezado'].str.replace('\t',' ')


df_merged.drop(['message_first'],axis=1,inplace=True)

df_merged.Encabezado = df_merged.Encabezado.str.replace(r'[_\.]', ' ', regex=True)# quito los '.' '_'
df_merged.Encabezado = df_merged.Encabezado.str.replace(r'\s+', ' ', regex=True).str.strip() # espacios de mas
df_merged.Encabezado = df_merged.Encabezado.str.replace(r' || ', '').str.strip() # espacios de mas

# %%
cerrado_df_unique_cut = df_merged.copy()

# %% [markdown]
# ## Contenido Robusto

# %%
# Aplicar la función
cerrado_df_unique_cut['Contenido'] = extraer_bloque_por_inc(cerrado_df_unique_cut)

# %%
cerrado_df_unique_cut['Contenido'] = cerrado_df_unique_cut['Contenido'].str.replace(r'(?m)^.*INC0.*\n?', '', regex=True)


cerrado_df_unique_cut['Contenido'] = cerrado_df_unique_cut['Contenido'].str.replace(r'\n{2,}', '\n', regex=True)# quito los saltos de linea de mas 
cerrado_df_unique_cut['Contenido'] = (
    cerrado_df_unique_cut['Contenido']
    .str.replace(r'[ ]{2,}', ' ', regex=True)
    .str.strip()
)

# %%
## capturo el formato de INCNNNN (12)valores numericos y todo lo que le sigue hasta mas de 3 /n saltos de linea seguidos.

# %%
cerrado_df_unique_cut['Plano'] = cerrado_df_unique_cut.Encabezado.str.split(' ').str[1].str.strip()
cerrado_df_unique_cut['Tipo de Averia'] = cerrado_df_unique_cut.Encabezado.str.split(' ').str[3].str.strip()
cerrado_df_unique_cut['Tipo de Averia'] = cerrado_df_unique_cut['Tipo de Averia'].str.replace(r'[*\+\]]', '', regex=True)
cerrado_df_unique_cut['Nodo'] = cerrado_df_unique_cut.Encabezado.str.split(' ').str[2].str.strip()

# %%
cerrado_df_unique_cut['Tipo de Averia'] = cerrado_df_unique_cut['Tipo de Averia'].fillna('PARCIAL')
cerrado_df_unique_cut['Tipo de Averia'] = cerrado_df_unique_cut['Tipo de Averia'].str.replace('¨','')

# %%
cerrado_df_unique_cut['Tipo de Averia'] = cerrado_df_unique_cut['Tipo de Averia'].replace({'APRCIAL':'PARCIAL','PACIAL':'PARCIAL'})

# %%
cerrado_df_unique_cut.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 572 entries, 0 to 571
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   timestamp       572 non-null    datetime64[ns]
#  1   sender          572 non-null    object
#  2   message         572 non-null    object
#  3   codigos_inc     572 non-null    object
#  4   Encabezado      572 non-null    object
#  5   Contenido       572 non-null    object
#  6   Plano           572 non-null    object
#  7   Tipo de Averia  572 non-null    object
#  8   Nodo            572 non-null    object
# dtypes: datetime64[ns](1), object(8)
# memory usage: 40.3+ KB

# %%
cerrado_df_unique_cut
# Out:
#               timestamp           sender  \
# 0   2025-07-21 09:24:00  +51 914 748 998
# 1   2025-07-21 09:24:00  +51 914 748 998
# 2   2025-07-21 09:24:00  +51 914 748 998
# 3   2025-07-21 09:24:00  +51 914 748 998
# 4   2025-07-21 09:24:00  +51 914 748 998
# ..                  ...              ...
# 567 2025-08-22 12:31:00  +51 914 748 998
# 568 2025-08-22 13:06:00  +51 914 748 998
# 569 2025-08-22 15:59:00  +51 989 291 014
# 570 2025-08-22 15:59:00  +51 989 291 014
# 571 2025-08-22 15:59:00  +51 989 291 014
#
#                                                message      codigos_inc  \
# 0    *Se actualiza averías (Incidencias y WOs)*\nNO...  INC000009132638
# 1    *Se actualiza averías (Incidencias y WOs)*\nNO...  INC000009132695
# 2    *Se actualiza averías (Incidencias y WOs)*\nNO...  INC000009132696
# 3    *Se actualiza averías (Incidencias y WOs)*\nNO...  INC000009132687
# 4    *Se actualiza averías (Incidencias y WOs)*\nNO...  INC000009132649
# ..                                                 ...              ...
# 567  *INC000009246771 TREP006_cmtsTrujillo04 PARCIA...  INC000009246771
# 568  *WO0000002296180 - CORTE DE ENERGIA COMERCIAL*...  INC000009247269
# 569  *INC000009248766 \tTRLH014_vcsTrujillo04 TOTAL...  INC000009248766
# 570  *INC000009248766 \tTRLH014_vcsTrujillo04 TOTAL...  INC000009248758
# 571  *INC000009248766 \tTRLH014_vcsTrujillo04 TOTAL...  INC000009248771
#
#                                            Encabezado  \
# 0      *INC000009132638 TRUJ161 cmtsTrujillo05 TOTAL*
# 1    *INC000009132695 TRUJ120 cmtsTrujillo05 PARCIAL*
# 2      *INC000009132696 TRUJ134 cmtsTrujillo05 TOTAL*
# 3       *INC000009132687 TRUJ122 vcsTrujillo04 TOTAL*
# 4     *INC000009132649 TRUJ123 vcsTrujillo03 PARCIAL*
# ..                                                ...
# 567  *INC000009246771 TREP006 cmtsTrujillo04 PARCIAL*
# 568   *INC000009247269 TRUJ131 vcsTrujillo03 PARCIAL*
# 569     *INC000009248766 TRLH014 vcsTrujillo04 TOTAL*
# 570   *INC000009248758 TRLH015-B oltTrujillo06 TOTAL*
# 571    *INC000009248771 TRLH020 cmtsTrujillo04 TOTAL*
#
#                                              Contenido      Plano  \
# 0    21-07 HI 07:52\nTecnico Marlon Cardenas\nEstim...    TRUJ161
# 1    21-07 HI 07:52\nTecnico Marlon Cardenas\nEstim...    TRUJ120
# 2    21-07 HI 07:52\nTecnico Marlon Cardenas\nEstim...    TRUJ134
# 3    21-07 HI 07:52\nTecnico Marlon Cardenas\nEstim...    TRUJ122
# 4    21-07 HI 07:52\nTecnico Marlon Cardenas\nEstim...    TRUJ123
# ..                                                 ...        ...
# 567  HI: 22/8/25 11:40\nTECNICO PEXT: **\nEstimado ...    TREP006
# 568  HI: 22/8/25 10:29\nTECNICO PEXT: **\nEstimado ...    TRUJ131
# 569  22/08 HI 15:40\nTecnico **\nse reporta caida t...    TRLH014
# 570  22/08 HI 15:40\nTecnico **\nse reporta caida t...  TRLH015-B
# 571  22/08 HI 15:40\nTecnico **\nse reporta caida t...    TRLH020
#
#     Tipo de Averia            Nodo
# 0            TOTAL  cmtsTrujillo05
# 1          PARCIAL  cmtsTrujillo05
# 2            TOTAL  cmtsTrujillo05
# 3            TOTAL   vcsTrujillo04
# 4          PARCIAL   vcsTrujillo03
# ..             ...             ...
# 567        PARCIAL  cmtsTrujillo04
# 568        PARCIAL   vcsTrujillo03
# 569          TOTAL   vcsTrujillo04
# 570          TOTAL   oltTrujillo06
# 571          TOTAL  cmtsTrujillo04
#
# [572 rows x 9 columns]

# %%
cerrado_df_unique_cut['Tipo de Averia'] = np.where(cerrado_df_unique_cut['Tipo de Averia'].isin(['PARCIAL','TOTAL']),
                                                                       cerrado_df_unique_cut['Tipo de Averia'],
                                                                       'OTRO')

# %%
cerrado_df_unique_cut['Tipo de Averia'].value_counts()
# Out:
# Tipo de Averia
# PARCIAL    340
# TOTAL      229
# OTRO         3
# Name: count, dtype: int64

# %% [markdown]
# ## Creo Fechas

# %% [markdown]
# ## Creo Fecha de inicio (robusto con Spacy):

# %%
# Procesamiento vectorizado con nlp.pipe
import spacy
from spacy.matcher import Matcher
import unicodedata


def normalizar_texto(texto):
    texto = texto.lower()
    if not any(c in 'áéíóúüñÁÉÍÓÚÜÑ' for c in texto):
        return texto
    return ''.join(c for c in unicodedata.normalize('NFD', texto)
                   if unicodedata.category(c) != 'Mn')


    
nlp = spacy.load("es_core_news_sm")
matcher = Matcher(nlp.vocab)

# Definir el patrón
pattern = [
    {"LEMMA": "tecnico","OP":'+'},
    {"TEXT": "se", "OP" : "?"},
    {"POS" : 'ADP','OP':'?'},
    {"POS" : "DET",'OP':'?'},
    {"LEMMA": {"IN": ["estar", "encontrar", "ir", "llegar", "movilizar", "instalo", "indicar","camino","plano"]}, "OP": "+"},
    {"POS" : 'ADP','OP':'?'},
    {"POS" : "DET",'OP':'?'},
    {"LEMMA": {"IN": ["plano", "ruta", "ubicación"]},"OP":'?'}
]

matcher.add("TECNICO_ACCION", [pattern])

# %% [markdown]
# ### test matcher patron

# %%
# Frases de prueba
frases = [
    'tecnico llega al plano',
    'tecnico se moviliza',
    'Técnico llega a plano',
    'Tecnico en camino',
    'tecnico se encuentra en el plano',
    'Técnico camino al plano',
    'tecnico instala',
    'tecnico indica',
    'Tecnico en plano',
    'Tecnico camino a plano',
    'Tecnico en el plano',
    'Técnico en plano',
    'tecnico llega al plano',
    'Tecnico llega al plano',
    'Tecnico atender',
    'Se llega al plano'
]
# Probar coincidencias
for frase in frases:
    texto_normalizado = normalizar_texto(frase)
    print(texto_normalizado)
    print('------------')
    doc = nlp(texto_normalizado)  # Normalizar a minúsculas
    for token in doc:
        print(token.text, token.lemma_)
    matches = matcher(doc)
    if matches:
        print(f":white_check_mark: COINCIDE: {frase}")
    else:
        print(f":x: NO COINCIDE: {frase}")
    print('------------------------')
# Out:
# tecnico llega al plano
# ------------
# tecnico tecnico
# llega llegar
# al al
# plano plano
# :white_check_mark: COINCIDE: tecnico llega al plano
# ------------------------
# tecnico se moviliza
# ------------
# tecnico tecnico
# se él
# moviliza movilizar
# :white_check_mark: COINCIDE: tecnico se moviliza
# ------------------------
# tecnico llega a plano
# ------------
# tecnico tecnico
# llega llegar
# a a
# plano plano
# :white_check_mark: COINCIDE: Técnico llega a plano
# ------------------------
# tecnico en camino
# ------------
# tecnico tecnico
# en en
# camino camino
# :white_check_mark: COINCIDE: Tecnico en camino
# ------------------------
# tecnico se encuentra en el plano
# ------------
# tecnico tecnico
# se él
# encuentra encontrar
# en en
# el el
# plano plano
# :white_check_mark: COINCIDE: tecnico se encuentra en el plano
# ------------------------
# tecnico camino al plano
# ------------
# tecnico tecnico
# camino camino
# al al
# plano plano
# :white_check_mark: COINCIDE: Técnico camino al plano
# ------------------------
# tecnico instala
# ------------
# tecnico tecnico
# instala instalo
# :white_check_mark: COINCIDE: tecnico instala
# ------------------------
# tecnico indica
# ------------
# tecnico tecnico
# indica indicar
# :white_check_mark: COINCIDE: tecnico indica
# ------------------------
# tecnico en plano
# ------------
# tecnico tecnico
# en en
# plano plano
# :white_check_mark: COINCIDE: Tecnico en plano
# ------------------------
# tecnico camino a plano
# ------------
# tecnico tecnico
# camino camino
# a a
# plano plano
# :white_check_mark: COINCIDE: Tecnico camino a plano
# ------------------------
# tecnico en el plano
# ------------
# tecnico tecnico
# en en
# el el
# plano plano
# :white_check_mark: COINCIDE: Tecnico en el plano
# ------------------------
# tecnico en plano
# ------------
# tecnico tecnico
# en en
# plano plano
# :white_check_mark: COINCIDE: Técnico en plano
# ------------------------
# tecnico llega al plano
# ------------
# tecnico tecnico
# llega llegar
# al al
# plano plano
# :white_check_mark: COINCIDE: tecnico llega al plano
# ------------------------
# tecnico llega al plano
# ------------
# tecnico tecnico
# llega llegar
# al al
# plano plano
# :white_check_mark: COINCIDE: Tecnico llega al plano
# ------------------------
# tecnico atender
# ------------
# tecnico tecnico
# atender atender
# :x: NO COINCIDE: Tecnico atender
# ------------------------
# se llega al plano
# ------------
# se él
# llega llegar
# al al
# plano plano
# :x: NO COINCIDE: Se llega al plano
# ------------------------

# %% [markdown]
# ### test in dataframe

# %%
def extraer_primer_match_detallado(texto):
    if pd.isna(texto) or not texto.strip():
        return None, None
    for linea in texto.split('\n'):
        linea_n = normalizar_texto(linea)
        doc = nlp(linea_n)
        matches = matcher(doc)
        if matches:
            # Obtener el texto que coincidió exactamente
            span_coincidencia = doc[matches[0][1]:matches[0][2]]
            return linea, span_coincidencia.text
    return None, None

# %%
cerrado_df_unique_cut.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 572 entries, 0 to 571
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   timestamp       572 non-null    datetime64[ns]
#  1   sender          572 non-null    object
#  2   message         572 non-null    object
#  3   codigos_inc     572 non-null    object
#  4   Encabezado      572 non-null    object
#  5   Contenido       572 non-null    object
#  6   Plano           572 non-null    object
#  7   Tipo de Averia  572 non-null    object
#  8   Nodo            572 non-null    object
# dtypes: datetime64[ns](1), object(8)
# memory usage: 40.3+ KB

# %%
df = pd.DataFrame()

# %%
# Aplicar y expandir resultados
cerrado_df_unique_cut[['primera_coincidencia', 'texto_match']] = cerrado_df_unique_cut['Contenido'].apply(
    lambda x: pd.Series(extraer_primer_match_detallado(x))
)

# %%
cerrado_df_unique_cut['Fecha de Llegada'] = cerrado_df_unique_cut['primera_coincidencia'].str.extract(r'^(\d{2}:\d*)(?=\D)')

cerrado_df_unique_cut['Fecha de Llegada'] = cerrado_df_unique_cut['Fecha de Llegada'].str.strip()
## si no hay digitos luego de los ":" completar con 0

# %%
cerrado_df_unique_cut['Fecha de Llegada'] = np.where(cerrado_df_unique_cut['Fecha de Llegada'].str.len() < 4,
                                                     cerrado_df_unique_cut['Fecha de Llegada'] + '00',
                                                     cerrado_df_unique_cut['Fecha de Llegada'])

# %%
cerrado_df_unique_cut[cerrado_df_unique_cut.codigos_inc == 'INC000009143321']
# Out:
#              timestamp           sender  \
# 68 2025-07-23 11:55:00  +51 914 748 998
#
#                                               message      codigos_inc  \
# 68  *Se actualiza averías (Incidencias y WOs)*\nNO...  INC000009143321
#
#                                        Encabezado  \
# 68  *INC000009143321 PIUC109 cmtsPiura03 PARCIAL*
#
#                                             Contenido    Plano Tipo de Averia  \
# 68  TECNICO PEXT: *Giuseppe Sernaque*\nEstimado at...  PIUC109        PARCIAL
#
#            Nodo Fecha de Llegada Completa
# 68  cmtsPiura03       2025-07-23 11:00:00

# %%
cerrado_df_unique_cut.drop(['texto_match','primera_coincidencia'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 cerrado_df_unique_cut.drop(['texto_match','primera_coincidencia'],axis=1,inplace=True)
#
# File D:\Scripts1\NLP\entorno\Lib\site-packages\pandas\core\frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
#    5593         level=level,
#    5594         inplace=inplace,
#    5595         errors=errors,
#    5596     )
#
# File D:\Scripts1\NLP\entorno\Lib\site-packages\pandas\core\generic.py:4807, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4805 for axis, labels in axes.items():
#    4806     if labels is not None:
# -> 4807         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4809 if inplace:
#    4810     self._update_inplace(obj)
#
# File D:\Scripts1\NLP\entorno\Lib\site-packages\pandas\core\generic.py:4849, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4847         new_axis = axis.drop(labels, level=level, errors=errors)
#    4848     else:
# -> 4849         new_axis = axis.drop(labels, errors=errors)
#    4850     indexer = axis.get_indexer(new_axis)
#    4852 # Case for non-unique axis
#    4853 else:
#
# File D:\Scripts1\NLP\entorno\Lib\site-packages\pandas\core\indexes\base.py:7136, in Index.drop(self, labels, errors)
#    7134 if mask.any():
#    7135     if errors != "ignore":
# -> 7136         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137     indexer = indexer[~mask]
#    7138 return self.delete(indexer)
#
# KeyError: "['texto_match', 'primera_coincidencia'] not found in axis"

# %%
# si la hora de llegada es mayor  a la hora de envio de mensaje(cierre) entonces es de un dia antes 
hora_llegada = pd.to_datetime(cerrado_df_unique_cut['Fecha de Llegada'],format="%H:%M").dt.time

hora_timestamp = cerrado_df_unique_cut['timestamp'].dt.time

condicion = hora_timestamp < hora_llegada



# Aplicar np.where para ajustar la fecha
cerrado_df_unique_cut['Fecha de Llegada_formated'] = np.where(
    condicion,
    (cerrado_df_unique_cut['timestamp'] - pd.Timedelta(days=1)),
    cerrado_df_unique_cut['timestamp']
)
cerrado_df_unique_cut['Fecha de Llegada_formated'] = cerrado_df_unique_cut['Fecha de Llegada_formated'].dt.date

cerrado_df_unique_cut['Fecha de Llegada_formated'] = cerrado_df_unique_cut['Fecha de Llegada_formated'].astype(str)

from datetime import datetime, timedelta

cerrado_df_unique_cut['Fecha de Llegada Completa'] = pd.to_datetime(cerrado_df_unique_cut['Fecha de Llegada_formated'] +' '+cerrado_df_unique_cut['Fecha de Llegada'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Scripts1\NLP\entorno\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Fecha de Llegada'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 2
#       1 # si la hora de llegada es mayor  a la hora de envio de mensaje(cierre) entonces es de un dia antes
# ----> 2 hora_llegada = pd.to_datetime(cerrado_df_unique_cut['Fecha de Llegada'],format="%H:%M").dt.time
#       4 hora_timestamp = cerrado_df_unique_cut['timestamp'].dt.time
#       6 condicion = hora_timestamp < hora_llegada
#
# File D:\Scripts1\NLP\entorno\Lib\site-packages\pandas\core\frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File D:\Scripts1\NLP\entorno\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Fecha de Llegada'

# %%
cerrado_df_unique_cut.drop(['Fecha de Llegada','Fecha de Llegada_formated'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 cerrado_df_unique_cut.drop(['Fecha de Llegada','Fecha de Llegada_formated'],axis=1,inplace=True)
#
# File D:\Scripts1\NLP\entorno\Lib\site-packages\pandas\core\frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
#    5593         level=level,
#    5594         inplace=inplace,
#    5595         errors=errors,
#    5596     )
#
# File D:\Scripts1\NLP\entorno\Lib\site-packages\pandas\core\generic.py:4807, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4805 for axis, labels in axes.items():
#    4806     if labels is not None:
# -> 4807         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4809 if inplace:
#    4810     self._update_inplace(obj)
#
# File D:\Scripts1\NLP\entorno\Lib\site-packages\pandas\core\generic.py:4849, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4847         new_axis = axis.drop(labels, level=level, errors=errors)
#    4848     else:
# -> 4849         new_axis = axis.drop(labels, errors=errors)
#    4850     indexer = axis.get_indexer(new_axis)
#    4852 # Case for non-unique axis
#    4853 else:
#
# File D:\Scripts1\NLP\entorno\Lib\site-packages\pandas\core\indexes\base.py:7136, in Index.drop(self, labels, errors)
#    7134 if mask.any():
#    7135     if errors != "ignore":
# -> 7136         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137     indexer = indexer[~mask]
#    7138 return self.delete(indexer)
#
# KeyError: "['Fecha de Llegada', 'Fecha de Llegada_formated'] not found in axis"

# %% [markdown]
# ### inspecion de resultados

# %%
cerrado_df_unique_cut.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 572 entries, 0 to 571
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   timestamp                  572 non-null    datetime64[ns]
#  1   sender                     572 non-null    object
#  2   message                    572 non-null    object
#  3   codigos_inc                572 non-null    object
#  4   Encabezado                 572 non-null    object
#  5   Contenido                  572 non-null    object
#  6   Plano                      572 non-null    object
#  7   Tipo de Averia             572 non-null    object
#  8   Nodo                       572 non-null    object
#  9   Fecha de Llegada Completa  237 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), object(8)
# memory usage: 44.8+ KB

# %%
for i in cerrado_df_unique_cut[cerrado_df_unique_cut['Fecha de Llegada Completa'].isna()].Contenido:
    print(i)
# Out:
# 21-07 HI 07:52
# Tecnico Marlon Cardenas
# Estimados, atender
# 09:20 se observa plano arriba, se notifica a BOSF
# *CERRADO* VALIDA BOSF <Se editó este mensaje.>
# 21-07 HI 07:52
# Tecnico Marlon Cardenas
# Estimados, atender
# 09:20 se observa plano arriba, se notifica a BOSF
# *CERRADO* VALIDA BOSF <Se editó este mensaje.>
# 21-07 HI 07:52
# Tecnico Marlon Cardenas
# Estimados, atender
# 09:20 se observa plano arriba, se notifica a BOSF
# *CERRADO* VALIDA BOSF <Se editó este mensaje.>
# 21-07 HI 07:52
# Tecnico Marlon Cardenas
# Estimados, atender
# 09:20 se observa plano arriba, se notifica a BOSF
# *CERRADO* VALIDA BOSF <Se editó este mensaje.>
# 21-07 HI 07:52
# Tecnico Marlon Cardenas
# Estimados, atender
# 09:20 se observa plano arriba, se notifica a BOSF
# *CERRADO* VALIDA BOSF <Se editó este mensaje.>
# HI: 21/7/25 09:31
# Tecnico Giuseppe Sernaque
# Estimados, atender
# *CERRADO* VALIDA BOSF PLANO RESTABLECIDO
# HI: 21/7/25 09:31
# Tecnico Giuseppe Sernaque
# Estimados, atender
# *CERRADO* VALIDA BOSF PLANO RESTABLECIDO
# HI: 21/7/25 09:31
# Tecnico Giuseppe Sernaque
# Estimados, atender
# *CERRADO* VALIDA BOSF PLANO RESTABLECIDO
# HI: 21/7/25 09:31
# Tecnico Giuseppe Sernaque
# Estimados, atender
# *CERRADO* VALIDA BOSF PLANO RESTABLECIDO
# HI: 21/7/25 09:31
# Tecnico Giuseppe Sernaque
# Estimados, atender
# *CERRADO* VALIDA BOSF PLANO RESTABLECIDO
# HI: 21/7/25 09:31
# Tecnico Giuseppe Sernaque
# Estimados, atender
# *CERRADO* VALIDA BOSF PLANO RESTABLECIDO
# HI 21-07 05:00
# 19:50 Tecnico se comunica con cliente y confirman corte de energia lado cliente
# Karla Magaly Guanilo Alvarado
# Calle gonzales parada 336
# se informa a BOSF y se procede a cierre
# *CERRADO BOSF*
# HI 22:51 21/07
# Tecnico pext: **
# Se observa plano restableciendo, se informa a BOSF revisar.
# Se procede al *CIERRE* de averia valida BOSF
# HI 06:00
# TÉCNICO PEXT: *MARLON CARDENAS
# Bosf verifica caída, está gestionando lista reciente de afectados.
# 06:22 Técnico atender.
# 10:16 se observa plano arriba, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# HI: 22/7/25 16:53
# TECNICO PEXT: LUIS FERNANDEZ
# EN PROGRAMACION
# 20:30 BOSF valida plano UP se procede al cierre
# *CERRADO BOSF*
# *WO0000002290655 - Resguardo GE – Monitoreo*
# HI: 22/7/25 16:53
# TECNICO PEXT: LUIS FERNANDEZ
# EN PROGRAMACION
# 20:30 BOSF valida plano UP se procede al cierre
# *CERRADO BOSF*
# *WO0000002290655 - Resguardo GE – Monitoreo*
# HI: 22/7/25 16:53
# TECNICO PEXT: LUIS FERNANDEZ
# EN PROGRAMACION
# 20:30 BOSF valida plano UP se procede al cierre
# *CERRADO BOSF*
# *WO0000002290655 - Resguardo GE – Monitoreo*
# HI: 22/7/25 16:53
# TECNICO PEXT: LUIS FERNANDEZ
# EN PROGRAMACION
# 20:30 BOSF valida plano UP se procede al cierre
# *CERRADO BOSF*
# *WO0000002290655 - Resguardo GE – Monitoreo*
# HI: 22/7/25 16:53
# TECNICO PEXT: LUIS FERNANDEZ
# EN PROGRAMACION
# 20:30 BOSF valida plano UP se procede al cierre
# *CERRADO BOSF*
# *WO0000002290655 - Resguardo GE – Monitoreo*
# HI: 22/7/25 16:53
# TECNICO PEXT: LUIS FERNANDEZ
# EN PROGRAMACION
# 20:30 BOSF valida plano UP se procede al cierre
# *CERRADO BOSF*
# *WO0000002290655 - Resguardo GE – Monitoreo*
# HI: 22/7/25 16:53
# TECNICO PEXT: LUIS FERNANDEZ
# EN PROGRAMACION
# 20:30 BOSF valida plano UP se procede al cierre
# *CERRADO BOSF*
# *WO0000002290655 - Resguardo GE – Monitoreo*
# HI: 22/7/25 16:53
# TECNICO PEXT: LUIS FERNANDEZ
# EN PROGRAMACION
# 20:30 BOSF valida plano UP se procede al cierre
# *CERRADO BOSF*
# *WO0000002290655 - Resguardo GE – Monitoreo*
# HI: 22/7/25 16:53
# TECNICO PEXT: LUIS FERNANDEZ
# EN PROGRAMACION
# 20:30 BOSF valida plano UP se procede al cierre
# *CERRADO BOSF*
# *WO0000002290655 - Resguardo GE – Monitoreo*
# HI: 22/7/25 16:53
# TECNICO PEXT: LUIS FERNANDEZ
# EN PROGRAMACION
# 20:30 BOSF valida plano UP se procede al cierre
# *CERRADO BOSF*
# *WO0000002290655 - Resguardo GE – Monitoreo*
# HI 22:00 22/07
# Tecnico pext: **
# En monitoreo por zona peligrosa, de no levantar se atendera a primera hora.
# Se observa plano con comportamiento ordinario, se informa a BOSF.
# 05:20 Se procede al *CIERRE* de averia valida BOSF.
# HI 22:00 22/07
# TÉCNICO PEXT: *
# En monitoreo por zona peligrosa, de no levantar se atendera a primera hora.
# Se observa plano restableciendo, se informa a BOSF revisar.
# Se procede al *CIERRE* de averia valida BOSF
# 05:35 Se procede al *CIERRE* de averia valida BOSF.
# HI 22:00 22/07
# Tecnico pext: **
# En monitoreo por zona peligrosa, de no levantar se atendera a primera hora.
# Se observa plano con comportamiento ordinario, se informa a BOSF.
# 05:35 Se procede al *CIERRE* de averia valida BOSF.
# HI 04:00
# TÉCNICO PEXT: *MARLON CARDENAS*
# 05:20 Técnico atender
# Se observa plano con comportamiento ordinario, se informa a BOSF.
# 06:03 Se procede al CIERRE de averia valida BOSF.
# HI: 23/7/25 12:13
# TECNICO PEXT: *Giuseppe Sernaque*
# Estimado atender averías
# *CERRADO* VALIDA BOSF
# HI: 23/7/25 12:13
# TECNICO PEXT: *Giuseppe Sernaque*
# Estimado atender averías
# *CERRADO* VALIDA BOSF
# HI: 23/7/25 12:13
# TECNICO PEXT: *Giuseppe Sernaque*
# Estimado atender averías
# *CERRADO* VALIDA BOSF
# HI: 23/7/25 14:25
# TECNICO PEXT: *Giuseppe Sernaque*
# Estimado atender averías
# *CERRADO* VALIDA BOSF
# HI: 23/7/25 14:25
# TECNICO PEXT: *Giuseppe Sernaque*
# Estimado atender averías
# 14:45 se observa plano arriba se notifica a BOSF
# *CERRADO* VALIDA BOSF
# HI: 23/7/25 15:20
# TÉCNICO PEXT: *MARLON CARDENAS*
# Estimado atender avería
# 15:34 se notifica a BOSF enviar lista de clientes ya que es remedy no figura
# *CERRADO* VALIDA BOSF
# HI: 23/7/25 12:31
# TÉCNICO PEXT: *ANDY CORREA*
# Estimado atender avería
# 12:50 – 15:10 solicitan apoyo con la movilidad
# 15:51 se observan planos arriba, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# HI: 23/7/25 12:31
# TÉCNICO PEXT: *ANDY CORREA*
# Estimado atender avería
# 12:50 – 15:10 solicitan apoyo con la movilidad
# 15:51 se observan planos arriba, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# HI: 23/7/25 17:10
# TECNICO PEXT: *Giuseppe Sernaque*
# Estimado atender avería
# *CERRADO* VALIDA BOSF
# 23/07 HI: 21:20
# TÉCNICO PEXT: *IVAN URQUIZA*
# 21:40 EN PROGRAMACION
# 22:23 Supervisor Roberto Guerra indica mantener en monitoreo por ser zona peligrosa
# 23:00 EN MONITOREO POR ZONA PELIGROSA
# 00:00 – 05:00 EN MONITOREO POR ZONA PELIGROSA
# Plano levantando se informa a BOSF.
# 06:22 Se procede al *CIERRE* de averia.
# HI: 24/7/25 08:10
# TÉCNICO PEXT: IVAN URQUIZA
# Estimado atender averia
# *CERRADO* VALIDA BOSF
# HI: 24/7/25 10:04
# TÉCNICO PEXT: *IVAN URQUIZA*
# Estimado atender averia
# *CERRADO* VALIDA BOSF
# HI: 24/7/25 09:24
# TÉCNICO PEXT: *IVAN URQUIZA*
# Estimado atender averia
# 10:41 tecnico indicó corte programado de 09:30 a 12:30 pm, adjunta evidencia, se notifica a BOSF
# *CERRADO* SE TRABAJARA CON LA WO VALIDA BOSF
# HI: 24/7/25 12:51
# TÉCNICO PEXT: *HENRY VIZLAO*
# Estimado atender averia
# 15:48 se notifica a BOSF plano arriba
# *CERRADO* VALIDA BOSF
# HI: 24/7/25 12:28
# TÉCNICO PEXT: *IVAN URQUIZA*
# Estimado atender averia
# 12:43 se indica a BOSF enviar lista de clientes ya que en REMEDY no figura
# 12:50 bosf envia lista de clientes
# *CERRADO* VALIDA BOSF
# HI 01:20
# TÉCNICO PEXT: *LUIS FERNANDEZ*
# Plano levantando, se informa a BOSF.
# 02:15 Se procede al *CIERRE* de averia valida BOSF.
# HI 03:40
# TÉCNICO PEXT: *LUIS FERNANDEZ*
# Se observa plano restableciendo, se informa a BOSF revisar.
# 04:39 Se procede al *CIERRE* de averia valida BOSF
# HI: 25/7/25 12:19
# TECNICO PEXT: * GIUSEPE SERNAQUE*
# Estimado atender averia
# 12:43 en camino al plano
# *CERRADO* VALIDA BOSF PLANO RESTABLECIDO
# 25-07 HI 16:50
# Tecnico *Dessi Mendoza*
# Estimados, atender
# 17:15 Tecnico procede a coordinar movilidad
# 17:56 Direcciones sin energía comercial
# 18:06 Niveles conformes, Se carga evidencias
# 18:13 fuente conforme
# 18:25 INC PASA A WO0000002291408
# *CERRADO* <Se editó este mensaje.>
# 25-07 HI 21:35
# Tecnico **
# estimados, atender
# 22:20 CLiente Marvin Alexander Rojas, casmiche mz B lote 14 , se carga audio con llamada a cliente quien informa corte de energia lado cliente. INC PASA A WO0000002291424
# *CERRADO*
# 25-07 HI 22:50
# Tecnico **
# Estimados, atender
# 23:23 Se observa plano presenta comportamiento regular, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# 26/07 HI: 01:05
# TEC.PEXT: *HENRY VIZLAO
# 01:20-02:00 EN PROGRAMACION
# 02:03 Se observan planos restableciendo, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# 26/07 HI: 01:05
# TEC.PEXT: *HENRY VIZLAO
# 01:20-02:00 EN PROGRAMACION
# 02:03 Se observan planos restableciendo, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# 26/07 HI: 01:05
# TEC.PEXT: *HENRY VIZLAO
# 01:20-02:00 EN PROGRAMACION
# 02:03 Se observan planos restableciendo, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# 26/07 HI: 01:05
# TEC.PEXT: *HENRY VIZLAO
# 01:20-02:00 EN PROGRAMACION
# 02:03 Se observan planos restableciendo, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# 26/07 HI: 01:05
# TEC.PEXT: *HENRY VIZLAO
# 01:20-02:00 EN PROGRAMACION
# 02:03 Se observan planos restableciendo, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# 26/07 HI: 01:05
# TEC.PEXT: *HENRY VIZLAO
# 01:20-02:00 EN PROGRAMACION
# 02:03 Se observan planos restableciendo, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# 26/07 HI: 01:05
# TEC.PEXT: *HENRY VIZLAO
# 01:20-02:00 EN PROGRAMACION
# 02:03 Se observan planos restableciendo, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# 26/07 HI: 01:05
# TEC.PEXT: *HENRY VIZLAO
# 01:20-02:00 EN PROGRAMACION
# 02:03 Se observan planos restableciendo, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# 26/07 HI: 01:05
# TEC.PEXT: *HENRY VIZLAO
# 01:20-02:00 EN PROGRAMACION
# 02:03 Se observan planos restableciendo, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# 26/07 HI: 07:55
# TEC.PEXT: *MARLON CARDENAS
# 08:04 Se solicita a BOSF lista de clientes
# 09:21 plano restablecido se cierra con BOSF
# *CERRADO BOSF*
# 26/07 HI: 07:30
# TEC.PEXT: *MARLON CARDENAS*
# 07:57 Tecnico llamo a clientes, cliente informa corte de energia en la zona. Se adjunta grabacion de llamada, Se notifica a BOSF
# ELIEZER DAVID SILVA , Av sanchez carrion 1198
# 08:01 En espera de validacion
# 09:56 BOSF brinda conformidad se procede a cierre
# *CERRADO BOSF*
# 26/07 HI: 07:30
# TEC.PEXT: *MARLON CARDENAS*
# EN PROGRAMACION
# 10:00 Tecnico informa retorno de energia en domicilios de abonados se cierra con BOSF
# *CERRADO BOSF* <Se editó este mensaje.>
# HI 11:39 26/07
# Tecnico pext. **
# planos restablecidos por retorno de energia se valida con BOSF y se procede al cierre
# *CERRADO BOSF*
# HI 11:39 26/07
# Tecnico pext. **
# planos restablecidos por retorno de energia se valida con BOSF y se procede al cierre
# *CERRADO BOSF*
# HI 11:39 26/07
# Tecnico pext. **
# planos restablecidos por retorno de energia se valida con BOSF y se procede al cierre
# *CERRADO BOSF*
# HI 11:39 26/07
# Tecnico pext. **
# planos restablecidos por retorno de energia se valida con BOSF y se procede al cierre
# *CERRADO BOSF*
# HI 11:39 26/07
# Tecnico pext. **
# planos restablecidos por retorno de energia se valida con BOSF y se procede al cierre
# *CERRADO BOSF*
# HI 11:39 26/07
# Tecnico pext. **
# 14:25 tecnico se comunica con clientes, Yadhira Rebeca Diaz Psj Gregorio albarracin 220, Clientes indican q están teniendo problemas todos los días con su energía electrica. se informa a BOSF para cierre
# 15:20 se valida con BOSF plano restablecido en automatico se procede al cierre
# *CERRADO BOSF*
# 26/07 HI: 20.40
# TEC.PEXT: *MARLON CARDENAS*
# 21:02 EN PROGRAMACION
# 21:26 Tecnico llamo a clientes quienes informan tener corte de energia en la zona, se adjunta grabaciones de llamadas
# SARA ARROYO VILLAREAL, Jr Alfonso Ugarte 491
# JENIFER RODRIGUEZ PRIETO, Jr alfonso ugarte 474
# 22:00 En espera de validacion
# Se procede al *CIERRE* de incidencia por avería corte de energía lado cliente.
# HI 09:10
# TÉCNICO PEXT: *LUIS FERNANDEZ*
# Técnico atender
# 10:00 Técnico se comunico con FELIX CASAMAYOR VILLANUEVA 964262923 y OSKAR AKIRA OKUYAMA KUAN 963294648 abonados de lista de afectados confirman que presentan corte de energía en sus domicilios y en zona, se sube evidencia en remedy se informa a BOSF.
# 10:09 Se procede al *CIERRE* de averia valida BOSF.
# HI 27/07/2025
# TÉCNICO PEXT: *MARLON CARDENAS*
# Se observa plano levantando se informa a BOSF.
# 12:50 Se procede al *CIERRE* de incidencia valida BOSF.
# HI 27/07/2025
# TÉCNICO PEXT: *IVAN URQUIZA*
# BOSF gestionando lista de afectados.
# 13:15 Técnico en breve atendera.
# Técnico verifica que abonados presentan corte domiciliario sin afectación a fuente y nivel conforme en tap, se informa a BOSF.
# 14:32 Se procede al *CIERRE* de incidencia por avería corte de energía lado cliente.
# 27-07 HI 19:30
# Tecnico **
# estimados, atender
# 20:47 Planos restablecidos
# *CERRADO*
# 27-07 HI 19:30
# Tecnico **
# estimados, atender
# 20:47 Planos restablecidos
# *CERRADO*
# 27-07 HI 19:30
# Tecnico **
# estimados, atender
# 20:47 Planos restablecidos
# *CERRADO*
# 27-07 HI 19:30
# Tecnico **
# estimados, atender
# 20:47 Planos restablecidos
# *CERRADO*
# 27-07 HI 19:30
# Tecnico **
# estimados, atender
# 20:47 Planos restablecidos
# *CERRADO*
# 27-07 HI 19:30
# Tecnico **
# estimados, atender
# 20:47 Planos restablecidos
# *CERRADO*
# 27-07 HI 19:30
# Tecnico **
# estimados, atender
# 20:47 Planos restablecidos
# *CERRADO*
# 27-07 HI 19:30
# Tecnico **
# estimados, atender
# 20:47 Planos restablecidos
# *CERRADO*
# 27-07 HI 23:00
# Tecnico **
# Estimados, atender
# 02:00 se verifica en gestores plano restablecido, se informa a BOSF para cierre
# 04:34 BOSF brinda conformidad se procede a cierre
# *CERRADO BOSF*
# HI 03:00 28/07
# técnico pext: **
# restablecido en automatico sin intervencion de pext
# *CERRADO BOSF*
# HI 03:00 28/07
# técnico pext: **
# restablecido en automatico sin intervencion de pext
# *CERRADO BOSF*
# HI: 28/7/25 9:42
# TÉCNICO PEXT: *GIUSEPPE SERNAQUE*
# Estimado atender averia
# *CERRADO* VALIDA BOSF PLANO ARRIBA
# HI 15:29 28/07
# técnico pext: **
# Restablecido en automatico sin intervencion d pext
# *CERRADO BOSF* <Se editó este mensaje.>
# HI: 29/7/25 09:13
# TECNICO PEXT: *Luis Fernandez*
# Estimado atender averia
# 09:51 tecnico realiza llamar al cliente NAYDU ARANA ESTABRIDIS 946184262, menciona retorno de energía, adjunta evidencia, se notifica a BOSF
# 09:59 -10:56 BOSF comparte nuevo listado
# 11:14 cliente indica corte de energía NAYDU ARANA ESTABRIDIS 946184262, adjun ta evidencia, se notifica a BOSF
# *CERRADO* VALIDA BOSF SE TRABAJARA CON LA WO
# HI: 29/7/25 12:21
# TECNICO PEXT: *MARLON CARDENAS*
# Estimado atender averia
# 12:38 tecnico llama al cliente AZUCENA VILLEGAS QUIROZ 947744651, indica corte de energía lado cliente, adjunta evidencia, se notifica a BOSF
# *CERRADO* SE TRABAJARÁ CON LA WO, VALIDA BOSF
# HI: 29/7/25 14:21
# TECNICO PEXT: *IVAN URQUIZA*
# Estimado atender averia
# 14:25 se indicó a BOSF enviar lista de clientes
# 14:27 BOSF envia lista de clientes
# 14:47 Claudia Tejada indica, estimados es zona comercial TRUJ078, es comportamiento normal los días domingos y feriados, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# HI 19:00 29/07
# Tecnico pext: *
# restablecido en automatico sin intervencion de pext
# *CERRADO BOSF*
# HI 19:05 29/07
# Tecnico pext: *
# Tecnico se comunica con abonados y confirman corte de enrgia lado cliente, se adjunta evidencias en remedy
# ARIANNE LLEMPEN CASTILLO<
# JORGE ROMERO RIVEROS
# *CERRADO BOSF*
# HI 23:20
# TÉCNICO PEXT: *MARLON CARDENAS*
# Técnico atender.
# 00:00 – 05:00 En programación, supervisión alerta zona peligrosa, de mantenerse afectación se atenderá a primera hora.
# Se observa plano está levantando, se informa a BOSF verificar.
# 05:17 Se procede al *CIERRE* de avería valida BOSF
# HI 02:25
# TÉCNICO PEXT: *GIUSEPE SERNAQUE*
# Técnico atender.
# Se observa plano está levantando, se informa a BOSF verificar.
# 07:34 Se procede al *CIERRE* de avería valida BOSF
# HI: 30/7/25 08:32
# TÉCNICO PEXT: MARLON CARDENAS
# Técnico atender
# 08:52 EN PROGRAMACION
# 13:18 se observa plano arriba, se notifica BOSF
# *CERRADO* VALIDA BOSF
# HI: 30/7/25 11:16
# Tecnico pext: *Marlon Cardenas*
# Estimado atender averia
# 11:20 – 12:03 se indica a BOSF enviar lista de clientes, ya que en remedy no figura
# 12:20 BOSF envia lista de clientes
# 13:32 CLIENTE: SANDRA VILLANUEVA DURAN, CEL: 900798360, CLIENTE LLAMO A SU PUESTO DE VENTAS E INFORMA QUE NO TIENE ENERGIA ELECTRICA Y EN LA ZONA SE SUFRE DE ESE TIPO DE PROBLEMAS SIEMPRE, adjunta evidencia, se notifica a bosf
# 13:37 BOSF indica llamar a otro cliente
# 14:06 CLIENTE: GARY EMANUEL GALINDO DIESTRA, CEL: 939198797
# OBS: INFORMA QUE NO TIENEN ENERGIA, PROBLEMA RECURRENTE EN LA ZONA, adjunta evidencia, se notifica a bosf
# *CERRADO* VALIDA BOSF SE TRABAJARA CON LA WO
# HI: 14:55 30/07
# TÉCNICO PEXT: *GIUSEPE SERNAQUE*
# Estimado atender averia
# 15:32 se observa plano arriba se notifica a BOSF
# *CERRADO* VALIDA BOSF
# HI: 14:55 30/07
# TÉCNICO PEXT: *GIUSEPE SERNAQUE*
# Estimado atender averia
# 15:59 se observa plano arriba se notifica a BOSF
# *CERRADO* VALIDA BOSF
# HI:15: 14 30/07
# TÉCNICO PEXT: *GIUSEPE SERNAQUE*
# Estimado atender averia
# 16:00 se observa plano arriba, se notifica BOSF
# *CERRADO* VALIDA BOSF
# 30/07 HI: 18:56
# TEC.PEXT: *GIUSEPPE SERNAQUE
# EN PROGRAMACION
# 19:51 Se observa plano restablecido en automatico, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# 30/07 HI: 21:33
# TEC.PEXT: *MARLON CARDENAS
# 21:55 EN PROGRAMACION
# 22:20 Tecnico llamo a clientes, quienes informar corte de energia en la zona. Se adjunta grabacion de llamadas, se notifica a BOSF
# LESLY MENDOZA NARVÁEZ 923038637
# LUZ REYES GONZÁLEZ 942202116
# 22:40 En espera de validación
# *CERRADO* VALIDA BOSF
# HI 06:30
# TÉCNICO PEXT: HENRY VIZLAO
# Técnico atender.
# *CERRADO* VALIDA BOSF PLANOS ARRIBA
# HI 06:30
# TÉCNICO PEXT: HENRY VIZLAO
# Técnico atender.
# *CERRADO* VALIDA BOSF PLANOS ARRIBA
# HI 06:30
# TÉCNICO PEXT: HENRY VIZLAO
# Técnico atender.
# *CERRADO* VALIDA BOSF PLANOS ARRIBA
# HI 06:30
# TÉCNICO PEXT: HENRY VIZLAO
# Técnico atender.
# *CERRADO* VALIDA BOSF PLANOS ARRIBA
# HI 06:30
# TÉCNICO PEXT: HENRY VIZLAO
# Técnico atender.
# *CERRADO* VALIDA BOSF PLANOS ARRIBA
# HI 06:30
# TÉCNICO PEXT: HENRY VIZLAO
# Técnico atender.
# *CERRADO* VALIDA BOSF PLANOS ARRIBA
# HI: 31/7/25 11:55
# PEXT: *GIUSEPPE SERNAQUE*
# Estimado atender averia
# *CERRADO* VALIDA BOSF
# HI: 31/7/25 11:55
# PEXT: *GIUSEPPE SERNAQUE*
# Estimado atender averia
# *CERRADO* VALIDA BOSF
# HI: 31/7/25 12:24
# TECNICO PEXT: *GIUSEPPE SERNAQUE*
# Estimado atender averia
# *CERRADO* VALIDA BOSF
# HI: 31/7/25 17:25
# TECNICO PEXT: *GIUSEPPE SERNAQUE*
# Estimado atender averia
# *CERRADO* VALIDA BOSF
# HI: 31/7/25 17:25
# TECNICO PEXT: *GIUSEPPE SERNAQUE*
# Estimado atender averia
# *CERRADO* VALIDA BOSF
# HI: 31/7/25 17:25
# TECNICO PEXT: *GIUSEPPE SERNAQUE*
# Estimado atender averia
# *CERRADO* VALIDA BOSF
# 31-07 HI 19:40
# Tecnico **
# Estimados, atender
# 20:46 Tecnico valida con clientes corte de energia en domicilios, de momento no se puede cargar evidencias por problemas en remedy.
# 21:20 se verifica restablecido, se solicita validacion
# 21:28 BOSF valida cierre
# *CERRADO*
# HI 01:00
# TÉCNICO PEXT: *MARLON CARDENAS*
# Se observa plano está levantando, se informa a BOSF verificar.
# 02:18 Se procede al *CIERRE* de avería valida BOSF <Se editó este mensaje.>
# HI 02:50
# TÉCNICO PEXT: *LUIS FERNANDEZ*
# Técnico atender.
# Se observa plano restableciendo, se informa a BOSF revisar.
# 03:49 Se procede al *CIERRE* de averia valida BOSF
# HI 05:55
# TÉCNICO PEXT: *MARLON CARDENAS*
# En programación.
# Se observa plano restableciendo, se informa a BOSF revisar.
# 08:04 Se procede al *CIERRE* de averia valida BOSF
# HI 05:55
# TÉCNICO PEXT: *MARLON CARDENAS*
# En programación.
# Se observa plano restableciendo, se informa a BOSF revisar.
# 08:04 Se procede al *CIERRE* de averia valida BOSF
# HI 05:55
# TÉCNICO PEXT: *MARLON CARDENAS*
# En programación.
# Se observa plano restableciendo, se informa a BOSF revisar.
# 08:04 Se procede al *CIERRE* de averia valida BOSF
# HI: 01/8/25 11:43
# TÉCNICO PEXT: GIUSEPE SERNAQUE
# Estimado por favor de atender averia
# 12:50 Plano restablecido, se informa al BOSF
# *CERRADO* VALIDA BOSF
# HI: 1/8/25 14:25
# PEXT: *MARLON CARDENAS*
# Estimado atender averia.
# 15:44 Se solicita lista de clientes al BOSF
# 16:38 - 17:52 TRUJ035 - Esta siendo afectado por un corte programado de 14:00 - 18:00 hrs
# 18:45 se solicita validacion
# 19:14 plano restablecido
# *CERRADO*
# 02/08 HI: 00:08
# TEC.PEXT: *HENRY VIZLAO
# PLANO RESTABLECIDO EN AUTOMATICO
# *CERRADO*
# 02/08 HI: 05:55
# TEC.PEXT: *MARLON CARDENAS
# EN PROGRAMACION
# 07:18 BOSF informa plano restablecido, personal de fibra culmino trabajos
# *CERRADO* VALIDA BOSF
# 02/08 HI: 01:20
# TEC.PEXT: *MARLON CARDENAS
# 01:40-06:00 EN PROGRAMACION
# 06:01 Tecnico en breve atendera
# 06:30 Se observa plano restableciendo
# 07:18 BOSF informa plano restablecido, personal de fibra culmino trabajos
# *CERRADO* VALIDA BOSF
# 02/08 HI: 05:51
# TEC.PEXT: *MARLON CARDENAS
# EN PROGRAMACION
# 07:17 Plano derivado a FO, personal de fibra realizando trabajos
# 07:36 BOSF informa plano restablecido, personal de fibra culmino trabajos
# *CERRADO* VALIDA BOSF
# HI 09:26 02/08
# Tecnico pext: **
# restablecido en autoamtico sin intervencion de pext
# *CERRADO BOSF*
# 02/08 HI: 18:17
# TEC.PEXT: *ANDY CORREA
# 18:40 EN PROGRAMACION
# 19:43 tecnico se comunico con cliente, quien informa corte de energia en la zona, se adjunta grabacion de llamada. Se notifica a BOSF
# ABANTO ABANTO YEISON, 992726953
# 20:04 En espera de validación
# *CERRADO* VALIDA BOSF
# 03.08 HI 00:20
# Tecnico **
# estimados, atender
# 00:54 bosf valida restablecido
# *CERRADO*
# 03.08 HI 00:20
# Tecnico *Marlon Cardenas*
# estimados, atender
# 23:35 TRUJ116_ Sin potencia óptica derivar a personal de fibra
# 00:00 - 03:30 afectacion por fibra.
# 06:20 BOSF valida restablecidos
# *CERRADO*
# 03.08 HI 00:20
# Tecnico *Marlon Cardenas*
# estimados, atender
# 23:35 TRUJ116_ Sin potencia óptica derivar a personal de fibra
# 00:00 - 03:30 afectacion por fibra.
# 06:20 BOSF valida restablecidos
# *CERRADO*
# 03.08 HI 00:20
# Tecnico *Marlon Cardenas*
# estimados, atender
# 23:35 TRUJ116_ Sin potencia óptica derivar a personal de fibra
# 00:00 - 03:30 afectacion por fibra.
# 06:20 BOSF valida restablecidos
# *CERRADO*
# 03.08 HI 00:20
# Tecnico *Marlon Cardenas*
# estimados, atender
# 23:35 TRUJ116_ Sin potencia óptica derivar a personal de fibra
# 00:00 - 03:30 afectacion por fibra.
# 06:20 BOSF valida restablecidos
# *CERRADO*
# 03.08 HI 00:20
# Tecnico *Marlon Cardenas*
# estimados, atender
# 23:35 TRUJ116_ Sin potencia óptica derivar a personal de fibra
# 00:00 - 03:30 afectacion por fibra.
# 06:20 BOSF valida restablecidos
# *CERRADO*
# 03.08 HI 00:20
# Tecnico *Marlon Cardenas*
# estimados, atender
# 23:35 TRUJ116_ Sin potencia óptica derivar a personal de fibra
# 00:00 - 03:30 afectacion por fibra.
# 06:20 BOSF valida restablecidos
# *CERRADO*
# 03.08 HI 00:20
# Tecnico *Marlon Cardenas*
# estimados, atender
# 23:35 TRUJ116_ Sin potencia óptica derivar a personal de fibra
# 00:00 - 03:30 afectacion por fibra.
# 06:20 BOSF valida restablecidos
# *CERRADO*
# HI 16:35
# TÉCNICO PEXT: *MARLON CARDENAS*
# En programación
# Técnico verifica que abonados presentan corte domiciliario sin afectación a fuente y nivel conforme en tap, se informa a BOSF.
# 17:44 Se procede al *CIERRE* de incidencia por avería corte de energía lado cliente.
# HI 17:35
# TÉCNICO PEXT: *HENRY VIZLAO*
# En programación.
# 18:00 Técnico atender. BOSF gestionando lista
# 19:20 Se verifica en gestores plano restablecido en automatico, se informa a BOSF para cierre
# 19:40 BOSF brinda conformidad se procede a cierre
# *CERRADO BOSF*
# HI 14:20
# TÉCNICO PEXT: *HENRY VIZLAO*
# En programación.
# 19:50 BOSF informa plano restablecido se procede al cierre
# *CERRADO BOSF*
# HI 14:20
# TÉCNICO PEXT: *HENRY VIZLAO*
# En programación.
# 19:50 BOSF informa plano restablecido se procede al cierre
# *CERRADO BOSF*
# HI: 4/8/25 10:21
# TECNICO PEXT: *HENRY VIZLAO*
# 10:26 Se indico a BOSF enviar lista de cliente, ya que en remedy no figura
# 10:50 BOSF envía lista de clientes
# 12:51 se observa plano arriba, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# HI 19:26 04/08
# Tecnico pext: **
# restablecido en automatico sin intervencion de pext
# *CERRADO BOSF*
# HI 20:13 04/08
# Tecnico pext: **
# Diego Wilfredo Mendoza franco
# Alexa margarita Pereyra esteves
# 21:25 Tecnico se comunica con abonados y confirman corte de energia lado cliente se cierra con BOSF
# *CERRADO BOSF*
# HI: 5/8/25 01:51
# PEXT: *Marlon Cardenas*
# En Programacion
# 03:27 Se valida plano arriba, se valida con BOSF
# *CERRADO* VALIDA BOSF
# HI: 5/8/25 04:33
# PEXT: *Henry Vislao*
# En Programacion
# 06:16 Se valida plano arriba en automatico, se notifica al BOSF
# *CERRADO* VALIDA BOSF
# HI: 5/8/25 04:35
# PEXT: *Jhony Aguilar*
# En Programacion.
# 08:30 – 09:37 Se observa plano restablecido en automatico, sin intervencion del pext, se notifica a bosf
# *CERRADO* VALIDA BOSF
# HI: 5/8/25 12:03
# TECNICO PEXT: *HENRY VIZLAO*
# Estimado atender avería
# 12:07 se indica a BOSF enviar lista de clientes
# *CERRADO* VALIDA BOSF
# HI: 5/8/25 09:21
# TECNICO PEXT: *HENRY VIZLAO*
# Estimado atender avería
# 12:44 se observa plano arriba, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# HI: 5/8/25 15:53
# TECNICO PEXT: *MARLON CARDENAS*
# Estimado atender averias
# 16:06 Tecnico verifica corte programado en planos donde indican direcciones, adjunta evidencia, se notifica a BOSF
# *CERRADO* SE TRABAJARA CON LA WO VALIDA BOSF
# HI: 5/8/25 15:53
# TECNICO PEXT: *MARLON CARDENAS*
# Estimado atender averias
# 16:06 Tecnico verifica corte programado en planos donde indican direcciones, adjunta evidencia, se notifica a BOSF
# *CERRADO* SE TRABAJARA CON LA WO VALIDA BOSF
# HI: 5/8/25 15:53
# TECNICO PEXT: *MARLON CARDENAS*
# Estimado atender averias
# 16:06 Tecnico verifica corte programado en planos donde indican direcciones, adjunta evidencia, se notifica a BOSF
# *CERRADO* SE TRABAJARA CON LA WO VALIDA BOSF
# HI: 5/8/25 16:22
# TECNICO PEXT: *HENRY VIZLAO*
# 16:31 se indica a BOSF enviar lista de cliente
# 17:16 se observa plano arriba se notifica a BOSF
# *CERRADO* VALIDA BOSF
# HI: 5/8/25 16:09
# TECNICO PEXT: *MARLON CARDENAS*
# Estimado atender avería
# 16:16 se indica a BOSF enviar lista de cliente
# 16:49 BOSF envía lista de clientes
# 17:16 se observa plano arriba se notifica a BOSF
# *CERRADO* VALIDA BOSF
# HI: 5/8/25 17:42
# TECNICO PEXT: *Marlon Cardenas*
# Estimado atender averia
# 06:06 corte programado en zona y afecta clientes en lista 17:30 a 18:30 pm, se notifica a BOSF
# restablecido en automatico por retorno de energia en la zona
# *CERRADO BOSF*
# HI: 5/8/25 17:42
# TECNICO PEXT: *Marlon Cardenas*
# Estimado atender averia
# 06:06 corte programado en zona y afecta clientes en lista 17:30 a 18:30 pm, se notifica a BOSF
# restablecido en automatico por retorno de energia en la zona
# *CERRADO BOSF*
# HI 19:41 05/08
# Tecnico pext: **
# tecnico se comunica con abonados los cuales confirman corte de energia lado cliente, se adjunta evidencias en remedy y se cierra con BOSF
# *CERRADO BOSF*
# HI: 6/8/25 03:46
# PEXT: MARLON CARDENAS
# En programacion
# Estimado atender averia
# 04:20 se solicita lista de clientes al BOSF
# 04:30 BOSF comparte lista de clientes
# 09:10 estimado atender averia
# 10:07 se observa plano arriba, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# HI: 6/8/25 14:13
# TECNICO PEXT: *Giuseppe Sernaque*
# Estimado atender averia
# 14:42 se observa plano arriba, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# HI: 6/8/25 14:57
# TECNICO PEXT: *HENRY VIZLAO*
# Estimado atender averia
# *CERRADO* VALIDA BOSF
# HI: 6/8/25 14:57
# TECNICO PEXT: *HENRY VIZLAO*
# Estimado atender averia
# *CERRADO* VALIDA BOSF
# HI: 6/8/25 14:57
# TECNICO PEXT: *HENRY VIZLAO*
# Estimado atender averia
# *CERRADO* VALIDA BOSF
# HI: 6/8/25 14:57
# TECNICO PEXT: *HENRY VIZLAO*
# Estimado atender averia
# *CERRADO* VALIDA BOSF
# HI: 6/8/25 14:57
# TECNICO PEXT: *HENRY VIZLAO*
# Estimado atender averia
# *CERRADO* VALIDA BOSF
# HI: 6/8/25 14:57
# TECNICO PEXT: *HENRY VIZLAO*
# Estimado atender averia
# *CERRADO* VALIDA BOSF
# HI: 6/8/25 14:57
# TECNICO PEXT: *HENRY VIZLAO*
# Estimado atender averia
# *CERRADO* VALIDA BOSF
# HI: 6/8/25 14:57
# TECNICO PEXT: *HENRY VIZLAO*
# Estimado atender averia
# *CERRADO* VALIDA BOSF
# HI: 6/8/25 14:57
# TECNICO PEXT: *HENRY VIZLAO*
# Estimado atender averia
# *CERRADO* VALIDA BOSF
# HI: 6/8/25 14:53
# TECNICO PEXT: *MARLON CARDENAS*
# Estimado atender averia
# 15:19 se observa plano arriba, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# HI: 6/8/25 15:29
# TECNICO PEXT: *MARLON CARDENAS*
# Estimado atender averia
# 15:44 se indicó a BOSF enviar lista de clientes
# 16:21 BOSF envia lista de clientes
# *CERRADO* VALIDA BOSF
# HI: 6/8/25 16:57
# TECNICO PEXT: *MARLON CARDENAS*
# Estimado atender averia
# 17:03 se indica a BOSF enviar lista de clientes
# *CERRADO* VALIDA BOSF
# 06/08 HI: 18:15
# TEC.PEXT: *FREDY VALVERVE
# 18:40 EN PROGRAMACION
# 19:05 Tecnico llama a clientes quienes informan tener corte de energia en la zona
# LUIS ALBERTO OYOLA RODRÍGUEZ 943966686
# JULIO ANDRÉS GONZÁLEZ SÁNCHEZ 914324412
# *CERRADO* VALIDA BOSF
# 06/08 HI: 18:15
# TEC.PEXT: *HENRY VIZLAO*
# 18:40-19:00 EN PROGRAMACION
# 20:00 tecnico en breve atendera
# 20:12 BOSF informa plano restablecido
# *CERRADO* VALIDA BOSF
# 06/08 HI: 20:10
# TEC.PEXT: *MARLON CARDENAS
# 20:30-21:00 EN PROGRAMACION
# 21:47 Se observa plano restbleciendo
# *CERRADO* VALIDA BOSF
# HI: 7/8/25 11:56
# TECNICO PEXT: *ANDY CORREA*
# Estimado atender averia
# 13:00 se observa plano arriba, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# HI: 7/8/25 11:33
# TECNICO PEXT: *HENRY VIZLAO*
# Estimado atender avería
# 11:42 se indicó a BOSF enviar lista de clientes
# 11:50 BOSF envía lista de clientes
# 14:14 se observa plano arriba, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# HI: 07/08/2025
# TECNICO PEXT: *MARLON CARDENAS*
# Estimado atender averia
# 16:53 se indica a BOSF enviar lista de clientes
# 17:24 a la espera de la lista de clientes
# *CERRADO* VALIDA BOSF
# 07-08 HI 19:30
# Tecnico **
# estimados, atender
# 21:15 a la espera de lista de clientes
# 22:20 corte de energia lado cliente, se carga evidencia de llamada. INC PASA A WO0000002293295
# *CERRADO*
# 07-08 HI 22:55
# Tecnico *Dessi Mendoza*
# Estimados, atender
# 23:10 bosf valida restablecido
# *CERRADO*
# HI: 7/8/25 23:16
# PEXT: *GIUSEPE SERNAQUE*
# En programación
# 03:51: Se observa plano restablecido en automatico, sin intervencion del pext, se notifica a bosf
# *CERRADO* VALIDA BOSF
# HI: 7/8/25 23:16
# PEXT: *GIUSEPE SERNAQUE*
# En programación
# 03:51: Se observa plano restablecido en automatico, sin intervencion del pext, se notifica a bosf
# *CERRADO* VALIDA BOSF
# HI: 8/8/25 10:14
# TECNICO PEXT: *HENRY VIZLAO*
# Estimado atender averia
# 10:30 se indica a bosf enviar lista de clientes
# 10:58 BOSF envia lista de clientes
# 11:37 se observa plano arriba se notifica a BOSF
# *CERRADO* VALIDA BOSF
# HI: 8/8/25 10:56
# TECNICO ´PEXT: *Dessi Mendoza*
# Estimado atender averia
# 11:02 se indica a bosf enviar lista de clientes
# 12:16 se observa plano arriba, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# HI: 8/8/25 15:04
# TECNICO PEXT: *Luis fernandez*
# Estimado atender averia
# 16:28 Plano continua con afectacion, confirmar atencion
# 17:07 Corte de energia lado cliente, Se carga evidencias de llamada INC PASA A WO0000002293700
# *CERRADO*
# 08/08 HI 18:00
# Tecnico *Luis Fernandez**
# estimados, atender
# 18:45 CORTE DOMICILIARIO, se carga evidencia de llamada
# 19:20 a la espera de WO
# 20:15 BOSF valida restablecido
# *CERRADO*
# HI: 8/8/25 15:12
# TECNICO ´PEXT: *Jhony Aguilar
# Estimado atender averia
# 16:56 Se llega al plano TRUJ146 Mall aventura plaza, se está gestionando accesos
# 16:57 Se verifica algunas tiendas sin energía eléctrica
# 17:17 Se continúa a la espera en TRUJ146, personal de mantenimiento de mall estan en averia dentro del Centro comercial
# 19:30 CC MALL AVENTURA continua con problemas eléctricos, no permiten instalar GGEE - mantener en monitoreo
# 20:15 Plano se encuentra con caida parcial
# 21:08 Se solicita validacion
# 22:08 INC PASA A WO0000002293714 para su monitoreo interno.
# *CERRADO*
# HI 09:16 09/08
# Tecnico pext: **
# restablecido en automatico sin intervencion de pext
# *CERRADO BOSF*
# HI 08:33 09/08
# Tecnico pext: **
# restablecido en automatico sin intervencion de pext
# *CERRADO BOSF*
# HI 08:33 09/08
# Tecnico pext: **
# restablecido en automatico sin intervencion de pext
# *CERRADO BOSF*
# HI 12:12 09/08
# Tecnico pext: **
# 15:40 Tecnico se comunica con abonados, clientes confirman corte de energia lado cliente, se adjunta evidencias en remedy se cierra con BOSF
# *CERRADO BOSF*
# HI 15:56 09/08
# Tecnico pext: **
# se verifica en gestores plano restablecido en automatico sin intervencion de pext
# *CERRADO BOSF* <Se editó este mensaje.>
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico **
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:20 BOSF informa planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico *HENRY VIZLAO
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:00 BOSF informa planos se mantienen con caída total
# 11:30 EN PROGRAMACION
# 11:44 BOSF valida planos restablecidos
# *CERRADO* VALIDA BOSF
# 10-08 HI 07:45
# Tecnico *HENRY VIZLAO
# estimados, atender
# 09:00-10:00 PLANOS AFECTADOS POR CORTE PROGRAMADO DE 6 AM A 10 AM
# 11:00 BOSF informa planos se mantienen con caída total
# 11:30 EN PROGRAMACION
# 11:44 BOSF valida planos restablecidos
# *CERRADO* VALIDA BOSF
# HI 20:18 10/08
# Tecnico pext: **
# restablecido en automatico sin intervencion de pext
# *CERRADO BOSF*
# HI 20:45 10/08
# Tecnico pext: **
# 22:40 - 04:00 plano se mantiene en monitoreo por ZONA PELIGROSA
# 04:50 Restablecido
# *CERRADO*
# 11-08 hi 07:40
# Tecnico **
# estimados, atender
# 08:00 Planos restablecidos, se solicita validacion
# *CERRADO* VALIDA BOSF
# 11-08 hi 07:40
# Tecnico **
# estimados, atender
# 08:00 Planos restablecidos, se solicita validacion
# *CERRADO* VALIDA BOSF
# 11-08 hi 07:40
# Tecnico **
# estimados, atender
# 08:00 Planos restablecidos, se solicita validacion
# *CERRADO* VALIDA BOSF
# HI: 11/8/25 14:58
# TECNICO PEXT: *MARLON CARDENAS*
# Estimado atender avería
# 15:07 se indica a BOSF enviar lista de clientes
# planos restablecidos y cerrados en automatico
# *CERRADO BOSF*
# HI: 11/8/25 14:58
# TECNICO PEXT: *MARLON CARDENAS*
# Estimado atender avería
# 15:07 se indica a BOSF enviar lista de clientes
# planos restablecidos y cerrados en automatico
# *CERRADO BOSF*
# HI 16:02 11/08
# técnico pext: **
# restablecido en automatico sin intervencion de pext
# *CERRADO BOSF*
# HI: 12/8/25 04:30
# PEXT: *ANDY CORREA*
# En Programacion
# 06:00 se observa plano restablecido en automatico, sin intervencion del pext, se notifica a bosf
# *CERRADO* VALIDA BOSF
# HI: 12/8/25 11:19
# TECNICO PEXT: *MARLON CARDENAS*
# Estimado atender averia
# 11:32 se indica a BOSF enviar lista de clientes
# 11:34 tecnico verifica corte programado y afecta planos TRUJ088 Y TRUJ087, adjunta evidencia, se notifica a BOSF
# *CERRADO* SE TRABAJARA CON LA WO VALIDA BOSF
# HI: 12/8/25 11:19
# TECNICO PEXT: *MARLON CARDENAS*
# Estimado atender averia
# 11:32 se indica a BOSF enviar lista de clientes
# 11:34 tecnico verifica corte programado y afecta planos TRUJ088 Y TRUJ087, adjunta evidencia, se notifica a BOSF
# *CERRADO* SE TRABAJARA CON LA WO VALIDA BOSF
# HI: *12/8/25 16:03*
# TECNICO PEXT: * LUIS FERNANDEZ *
# Estimado atender avería
# 17:05 se observa plano arriba, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# HI 19:25 12/08
# Tecnico pext: **
# Tecnico se comunica con abonado e informa corte de energia lado cliente se adjunta evidencia en remedy y se cierra con BOSF
# *CERRADO BOSF*
# HI 19:00 12/08
# Tecnico pext: *Giuseppe Sernaque
# 20:40 en breve se moviliza cuadrilla
# 21:30 tecnico informa que vigilancia no da acceso por ser urbanización cerrada , por favor de mantener en monitoreo de persistir avería se atenderá a primera hora
# 21:50 pendiente por accesos, se atenderá a primera hora.
# 21:55 se valida con BOSF plano restablecido se procede al cierre
# *CERRADO BOSF*
# HI 21:12 12/08
# Tecnico pext: **
# pendiente por zona peligrosa, de persistir se atenderá a primera hora
# 12:25 Se observa plano restablecido en automatico, sin intervencion del pext, se notifica a bosf
# *CERRADO* VALIDA BOSF <Se editó este mensaje.>
# HI 21:54 12/08
# Tecnico pext: **
# pendiente por zona peligrosa, de persistir se atenderá a primera hora
# 00:40 Se observa plano restablecido en automatico, sin intervencion del pext, se notifica a bosf
# *CERRADO* VALIDA BOSF <Se editó este mensaje.>
# HI 22:41 12/08
# Tecnico pext: **
# pendiente por zona peligrosa, de persistir se atenderá a primera hora
# 22:55 SE OBSERVA PLANO RESTABLECIDO EN AUTOMATICO, SIN INTERVENCION DEL PEXT, SE NOTIFICA A BOSF
# *CERRADO* VALIDA BOSF.
# HI: 13/8/25 17:47
# TECNICO PEXT: *IVAN URQUIZA*
# Estimado atender averia
# 18:22 Plano restablecido, se cerro en automática
# *CERRADO*
# 13/08 HI: 18:41
# TEC.PEXT: *HENRY VIZLAO
# 18:55 Supervisor Danny Huamanchumo informa, que plano se encuentra en residencial cerrada y no se permite realizar trabajos después de las 6 PM.
# 19:00 EN MONITOREO
# 19:41 Se observa plano restablecido, se notifica a BOSF
# 20:00 En espera de validacion
# *CERRADO* VALIDA BOSF
# 13/08 HI: 21:00
# TEC.PEXT: *MARLON CARDENAS
# EN PROGRAMACION
# 21:58 tecnico llamo a cliente, quien informa tener corte de energia en la zona. Se adjunta grabacion de llamada.
# JULIA VASQUEZ TICLIA 982256857
# 22:18 Se notifica BOSF para valdiacion
# 22:45 En espera de validación
# *CERRADO* VALIDA BOSF
# 13/08 HI: 21:00
# TEC.PEXT: *MARLON CARDENAS
# 21:58 tecnico llamo a cliente, quien informa tener corte de energia en la zona. Se adjunta grabacion de llamada.
# ELSA RISCO LLAJARUNA 968951611
# 22:18 Se notifica BOSF para valdiacion
# 22:45 En espera de validación
# *CERRADO* VALIDA BOSF
# 13/08 HI: 21:00
# TEC.PEXT: *MARLON CARDENAS
# 21:58 tecnico llamo a cliente, quien informa tener corte de energia en la zona. Se adjunta grabacion de llamada.
# VIOLETA RODRIGUEZ RUIZ 948397569
# 22:18 Se notifica BOSF para valdiacion
# 22:45 En espera de validación
# *CERRADO* VALIDA BOSF
# HI: 14/8/25 09:35
# TEC.PEXT: *HENRY VIZLAO*
# Estimado atender avería
# 11:00 se observa planos arriba, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# HI: 14/8/25 09:35
# TEC.PEXT: *HENRY VIZLAO*
# Estimado atender avería
# 11:00 se observa planos arriba, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# 14-08 HI 21:00
# Tecnico **
# estimados, atender
# 22:08 Restablecido, se solicita validacion
# 22:25 RESTABLECIDO
# *CERRADO*
# 14-08 HI 21:00
# Tecnico **
# estimados, atender
# 22:08 Restablecido, se solicita validacion
# 22:25 RESTABLECIDO
# *CERRADO*
# 14-08 HI 19:30
# Tecnico **
# estimados, atender
# 22:08 Restablecido, se solicita validacion
# 22:25 RESTABLECIDO
# *CERRADO*
# 14-08 HI 22:30
# Tecnico *Marlon Cardenas*
# estimados, atender
# 22:50 sup. informa explosion en la zona, mantener en monitoreo por corte de energía
# 23:45 Se observa plano restablecido en automatico, sin intervencion del pext, se notifica a bosf
# *CERRADO* VALIDA BOSF
# 14-08 HI 22:30
# Tecnico *Marlon Cardenas*
# estimados, atender
# 22:50 sup. informa explosion en la zona, mantener en monitoreo por corte de energía
# 23:45 Se observa plano restablecido en automatico, sin intervencion del pext, se notifica a bosf
# *CERRADO* VALIDA BOSF
# 14-08 HI 22:30
# Tecnico *Marlon Cardenas*
# estimados, atender
# 22:50 sup. informa explosion en la zona, mantener en monitoreo por corte de energía
# 23:45 Se observa plano restablecido en automatico, sin intervencion del pext, se notifica a bosf
# *CERRADO* VALIDA BOSF
# 14-08 HI 22:30
# Tecnico *Marlon Cardenas*
# estimados, atender
# 22:50 sup. informa explosion en la zona, mantener en monitoreo por corte de energía
# 23:45 Se observa plano restablecido en automatico, sin intervencion del pext, se notifica a bosf
# *CERRADO* VALIDA BOSF
# 14-08 HI 22:30
# Tecnico *Marlon Cardenas*
# estimados, atender
# 22:50 sup. informa explosion en la zona, mantener en monitoreo por corte de energía
# 23:45 Se observa plano restablecido en automatico, sin intervencion del pext, se notifica a bosf
# *CERRADO* VALIDA BOSF
# 14-08 HI 22:30
# Tecnico *Marlon Cardenas*
# estimados, atender
# 22:50 sup. informa explosion en la zona, mantener en monitoreo por corte de energía
# 23:45 Se observa plano restablecido en automatico, sin intervencion del pext, se notifica a bosf
# *CERRADO* VALIDA BOSF
# 14-08 HI 22:30
# Tecnico *Marlon Cardenas*
# estimados, atender
# 22:50 sup. informa explosion en la zona, mantener en monitoreo por corte de energía
# 23:45 Se observa plano restablecido en automatico, sin intervencion del pext, se notifica a bosf
# *CERRADO* VALIDA BOSF
# 14-08 HI 22:30
# Tecnico *Marlon Cardenas*
# estimados, atender
# 22:50 sup. informa explosion en la zona, mantener en monitoreo por corte de energía
# 23:45 Se observa plano restablecido en automatico, sin intervencion del pext, se notifica a bosf
# *CERRADO* VALIDA BOSF
# 14-08 HI 22:30
# Tecnico *Marlon Cardenas*
# estimados, atender
# 22:50 sup. informa explosion en la zona, mantener en monitoreo por corte de energía
# 23:45 Se observa plano restablecido en automatico, sin intervencion del pext, se notifica a bosf
# *CERRADO* VALIDA BOSF
# 14-08 HI 22:30
# Tecnico *Marlon Cardenas*
# estimados, atender
# 22:50 sup. informa explosion en la zona, mantener en monitoreo por corte de energía
# 23:45 Se observa plano restablecido en automatico, sin intervencion del pext, se notifica a bosf
# *CERRADO* VALIDA BOSF
# 14-08 HI 22:30
# Tecnico Marlon Cardenas
# estimados, atender
# 22:50 sup. informa explosion en la zona, mantener en monitoreo por corte de energía
# 02:30 Se observa plano restablecido en automatico, sin intervencion del pext, se notifica a bosf
# *CERRADO* VALIDA BOSF
# HI: 15/8/25 12:11
# TECNICO PEXT: *ANDY CORREA*
# Estimado atender avería
# 13:03 tecnico coordina movilización
# 13:58 se observa plano arriba, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# 17-08 hi 17:00
# Tecnico **
# Estimados, se reporta caida total
# 17:55 Planos restablecidos
# *CERRADO*
# 17-08 hi 17:00
# Tecnico **
# Estimados, se reporta caida total
# 17:55 Planos restablecidos
# *CERRADO*
# 15-08 HI 18:00
# Tecnico *Giuseppe Sernaque*
# estimados, se reporta caida parcial
# 18:43 Se envia lista de clientes
# 19:29 BOSF valida restablecidos
# *CERRADO*
# 15-08 HI 18:00
# Tecnico *Giuseppe Sernaque*
# estimados, se reporta caida parcial
# 18:43 Se envia lista de clientes
# 19:29 BOSF valida restablecidos
# *CERRADO*
# 15-08 HI 20:00
# Tecnico *Marlon Cardenas*
# estimados, atender
# 21:16 Clientes indican retorno de energía comercial
# 22:00 BOSF valida restablecido
# *CERRADO*
# HI 11:48 16/08
# Tecnico pext: **
# en programacion
# 13:05 tecnico se comunica con cliente Yadhira Diaz Bacilio, cliente indica q hace 1 mes están teniendo problemas todos los días con su energía eléctrica en la zona y Hoy día hace 2 horas q se fue la luz.
# 13:20 BOSF brinda conformidad se procede a cierre corte de energia lado cliente
# *CERRADO BOSF*
# HI 13:12 16/08
# Tecnico pext: **
# 14:00 tecnico se comunica con cliente Cecilia Reyes Alfaro
# Mz A lote 27 quien informa corte de energia lado cliente, se informa a BOSF para cierre
# 14:35 se cierra con BOSF corte de energia lado cliente
# *CERRADO BOSF*
# HI 13:25 16/08
# Tecnico pext: *Marlon Cardenas*
# 17:05 tecnico lega al plano informa corte de energia lado cliente niveles en taps ok, fuente con voltaje ok, se informa a BOSF para cierre
# 17:40 se valida con BOSF y se procede al cierre
# *CERRADO BOSF*
# HI 08:40 16/08
# Tecnico pext: **
# en programación
# 11:45 - 17:15 *corte programado 8am - 5pm*
# 17:40 plano restablecido por retorno de energia se procede a cierre
# *CERRADO BOSF*
# HI 08:40 16/08
# Tecnico pext: **
# en programación
# 11:45 - 17:15 *corte programado 8am - 5pm*
# 18:05 Planos restablecidos se informa bosf para cierre
# *CERRADO* VALIDA BOSF
# HI 08:40 16/08
# Tecnico pext: **
# en programación
# 11:45 - 17:15 *corte programado 8am - 5pm*
# 18:05 Planos restablecidos se informa bosf para cierre
# *CERRADO* VALIDA BOSF
# HI 08:40 16/08
# Tecnico pext: **
# en programación
# 11:45 - 17:15 *corte programado 8am - 5pm*
# 18:05 Planos restablecidos se informa bosf para cierre
# *CERRADO* VALIDA BOSF
# 16/08 HI: 20:50
# TEC.PEXT: *SANTIAGO MENDOZA*
# Plano arriba
# *CERRADO* VALIDA BOSF
# 17-08 HI 06:45
# Tecnico *Luis Fernandez*
# Estimados, atender
# 08:30 Se observan planos restablecidos, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# 17-08 HI 06:45
# Tecnico *Luis Fernandez*
# Estimados, atender
# 08:30 Se observan planos restablecidos, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# 17-08 HI 06:45
# Tecnico *Luis Fernandez*
# Estimados, atender
# 08:30 Se observan planos restablecidos, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# 17-08 HI 06:45
# Tecnico *Luis Fernandez*
# Estimados, atender
# 08:30 Se observan planos restablecidos, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# 17-08 HI 06:45
# Tecnico *Luis Fernandez*
# Estimados, atender
# 08:30 Se observan planos restablecidos, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# 17-08 HI 06:45
# Tecnico *Luis Fernandez*
# Estimados, atender
# 08:30 Se observan planos restablecidos, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# 17-08 HI 06:45
# Tecnico *Luis Fernandez*
# Estimados, atender
# 08:30 Se observan planos restablecidos, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# 17-08 HI 06:45
# Tecnico *Luis Fernandez*
# Estimados, atender
# 08:30 Se observan planos restablecidos, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# 17-08 HI 06:45
# Tecnico *Luis Fernandez*
# Estimados, atender
# 08:30 Se observan planos restablecidos, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# 17/08 HI: 10:26
# TEC.PEXT: *ANDY CORREA
# EN PROGRAMACION
# 10:50 Tecnico en breve atendera
# 11:20 Tecnico informa: Cuadrilla dorsal esta en ruta a Cajabamba , se atenderá avería a su regreso
# EN PROGRAMACION
# Se observa plano restablecido, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# 17-08 HI 07:30
# Tecnico *Henrry Vislao
# EN PROGRAMACION
# *Corte programado hasta la 1 PM*
# 13:20 Electrica aun en zona realizando trabajos
# 13:45 Se observa plano restablecido, se notifica a BOSF
# *CERRADO* VALIDA BOSF
# 17-08 HI 06:45
# Tecnico *Luis Fernandez
# EN PROGRAMACION
# *CORTE PROGRAMADO HASTA LAS 6 PM*
# BOSF informa que plano aun no levanta en su totalidad se mantiene en monitoreo
# 19:05 BOSF valida plano up se procede al cierre
# *CERRADO BOSF*
# 17-08 HI 06:45
# Tecnico *Luis Fernandez
# EN PROGRAMACION
# *CORTE PROGRAMADO HASTA LAS 6 PM*
# BOSF informa que plano aun no levanta en su totalidad se mantiene en monitoreo
# 19:05 BOSF valida plano up se procede al cierre
# *CERRADO BOSF*
# HI 18:25 17/08
# Tecnico pext: **
# se verifica en gestores plano restablecido en automatico se cierra con bosf
# *CERRADO BOSF*
# HI 18:56 17/08
# Tecnico pext: *Luis Fernandez*
# 19:40 Tecnico se comunica con abonados informa corte de energia lado cliente, se cierra con bosf
# *CERRADO BOSF* <Se editó este mensaje.>
# HI 19:55 17/08
# Tecnico pext: **
# Tecnico se comunica con abonado y confirma corte de energia lado cliente se cierra con BOSF
# *CERRADO BOSF*
# HI 20:20 17/08
# TECNICO PEXT: **
# restablecidos en automatico sin intervencion de pext
# *CERRADO BOSF*
# HI 20:20 17/08
# TECNICO PEXT: **
# restablecidos en automatico sin intervencion de pext
# *CERRADO BOSF*
# HI 22:02 17/08
# Tecnico pext: **
# 01:30 comportamiento regular en el plano
# *CERRADO*
# HI 19:21 18/08
# Tecnico pext: **
# tecnico se comunica con abonados via telefonica el cual confirman corte de energia lado cliente, se informa a BOSF para cierre
# 21:15 plano restablecido en automatico sin intervencion de pext
# *CERRADO BOSF*
# HI 21:56 18/08
# Tecnico pext: **
# en programación
# 00:30 Se observa plano restablecido en automatico, sin intervencion del pext, se notifica a bosf
# *CERRADO* VALIDA BOSF
# HI 22:26 18/08
# Tecnico pext: **
# en programación
# 00:30 Se observa plano restablecido en automatico, sin intervencion del pext, se notifica a bosf
# *CERRADO* VALIDA BOSF
# HI 21:56 18/08
# Tecnico pext: **
# 00:30 Se observa plano restablecido en automatico, sin intervencion del pext, se notifica a bosf
# *CERRADO* VALIDA BOSF
# HI: 19/8/25 00:47
# PEXT: * *
# En programación
# Estimado atender averia
# 03:00 Se observa plano restablecido en automatico, sin intervencion del pext, se notifica a bosf
# *CERRADO* VALIDA BOSF
# HI: 18/8/25 00:25
# PEXT: *MARLON CARDENAS*
# En Programacion
# Estimado atender averia
# 03:00 Se observa plano restablecido en automatico, sin intervencion del pext, se notifica a bosf
# *CERRADO* VALIDA BOSF
# HI: 19/8/25 00:47
# PEXT: * *
# En programación
# Estimado atender averia
# 03:00 Se observa plano restablecido en automatico, sin intervencion del pext, se notifica a bosf
# *CERRADO* VALIDA BOSF
# HI 18:40 19/08
# Tecnico pext: **
# PLANO CUENTA CON WO DE CORTE DE ENERGIA LADO CLIENTE WO0000002295574 - CORTE DE ENERGIA LADO CLIENTE
# *CERRADO BOSF*
# HI 19:26 19/08
# Tecnico pext: **
# Restablecido en automatico sin intervencion de pext
# *CERRADO BOSF*
# HI 23:06 19/08
# Tecnico pext: **
# 01:00 Se observa plano restablecido en automatico, sin intervencion del pext, se notifica a bosf
# *CERRADO* VALIDA BOSF
# HI: 20/8/25 09:53
# TECNICO PEXT: **
# Estimado atender avería
# 10:10 se notifica a BOSF enviar lista de clientes
# *CERRADO* PLANO ARRIBA VALIDA BOSF
# HI: 20/8/25 09:53
# TECNICO PEXT: **
# Estimado atender avería
# 10:10 se notifica a BOSF enviar lista de clientes
# *CERRADO* VALIDA BOSF
# HI: 20/8/25 11:40
# TECNICO PEXT: *ANDY CORREA*
# Estimado atender avería
# 12:27 tecnico llama a cliente indica q no tiene energía eléctrica, kevin Cieza Bustamante 981762360, adjunta evidencia, se notifica a BOSF
# *CERRADO* SE TRABAJARA CON LA WO VALIDA BOSF
# HI 19:21 20/08
# Tecnico pext: **
# restablecido en automatico sin intervencion de pext
# *CERRADO BOSF*
# HI 19:21 20/08
# Tecnico pext: **
# restablecido en automatico sin intervencion de pext
# *CERRADO BOSF*
# HI 20:23 20/08
# Tecnico pext: **
# restablecido en automatico sin intervencion de pext
# *CERRADO BOSF*
# HI: 21/8/25 11:06
# TECNICO PEXT: *Marlon Cardenas*
# Estimado atender avería
# 11:52 se notifica a BOSF enviar lista de clientes
# 12:28 BOSF envía lista de clientes
# 12:38 se observa plano arriba se notifica a BOSF
# *CERRADO* VALIDA BOSF
# HI: 22/8/25 11:40
# TECNICO PEXT: **
# Estimado atender avería
# 11:57 se notifica a BOSF enviar lista de clientes
# *CERRADO* VALIDA BOSF PLANO ARRIBA
# HI: 22/8/25 11:40
# TECNICO PEXT: **
# Estimado atender avería
# 12:21 se observa plano arriba se notifica a BOSF
# *CERRADO* VALIDA BOSF PLANO RESTABLECIDO
# 22/08 HI 15:40
# Tecnico **
# se reporta caida total
# 15:59 Planos restablecidos
# *CERRADO*
# 22/08 HI 15:40
# Tecnico **
# se reporta caida total
# 15:59 Planos restablecidos
# *CERRADO*
# 22/08 HI 15:40
# Tecnico **
# se reporta caida total
# 15:59 Planos restablecidos
# *CERRADO*

# %%
cerrado_df_unique_cut[cerrado_df_unique_cut['Fecha de Llegada Completa'].isna()][['codigos_inc','Contenido']].to_clipboard()

# %%
cerrado_df_e_m = cerrado_df_unique_cut

# %%
cerrado_df_e_m['Fecha de Incidencia'] = cerrado_df_e_m['Contenido'].str.extract(r'(?im)^(.*\bHI\b.*)$', expand=False)

# %% [markdown]
# ### Fecha de reporte(en base al merge)

# %%
# tomo el INC busco en el que tiene duplicados

# %%
### Fecha reporte = Fecha del primer mensaje 
### Fecha de Incidencia = Dentro del mensaje 
### Fecha de fin  de trabajo = Fecha del ultimo mensaje

# %% [markdown]
# ### df con los primeros mensajes por INC

# %%
df_inc_e_F = df_inc_e_F.rename(columns={'timestamp':'Fecha de Reporte'})

# %%
cerrado_df_e_m = pd.merge(cerrado_df_unique_cut,df_inc_e_F[['codigos_inc','Fecha de Reporte']],on='codigos_inc',how='left')

# %%
cerrado_df_e_m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 572 entries, 0 to 571
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   timestamp                  572 non-null    datetime64[ns]
#  1   sender                     572 non-null    object
#  2   message                    572 non-null    object
#  3   codigos_inc                572 non-null    object
#  4   Encabezado                 572 non-null    object
#  5   Contenido                  572 non-null    object
#  6   Plano                      572 non-null    object
#  7   Tipo de Averia             572 non-null    object
#  8   Nodo                       572 non-null    object
#  9   Fecha de Llegada Completa  237 non-null    datetime64[ns]
#  10  Fecha de Incidencia        572 non-null    object
#  11  Fecha de Reporte           572 non-null    datetime64[ns]
# dtypes: datetime64[ns](3), object(9)
# memory usage: 53.8+ KB

# %%
cerrado_df_e_m[cerrado_df_e_m.codigos_inc == 'INC000009165964']
# Out:
#               timestamp           sender  \
# 220 2025-07-31 16:49:00  +51 914 748 998
#
#                                                message      codigos_inc  \
# 220  *INC000009168013 PIUR044_cmtsPiura03 TOTAL*\nH...  INC000009165964
#
#                                           Encabezado  \
# 220  *INC000009165964 TRLH008 vcsTrujillo04 PARCIAL*
#
#                                              Contenido    Plano  \
# 220  HI: 31/7/25 12:15\nTECNICO PEXT: *MARLON CARDE...  TRLH008
#
#     Tipo de Averia           Nodo Fecha de Llegada Completa  \
# 220        PARCIAL  vcsTrujillo04       2025-07-31 14:27:00
#
#     Fecha de Incidencia    Fecha de Reporte
# 220   HI: 31/7/25 12:15 2025-07-31 12:17:00

# %% [markdown]
# ### Fecha de Incidencia(Robusto)

# %%
import re
import numpy as np
cerrado_df_e_m['Fecha de Incidencia'] = cerrado_df_e_m['Contenido'].str.extract(r'(?im)^(.*\bHI\b.*)$', expand=False)

# %%
cerrado_df_e_m_d = cerrado_df_e_m

# %%
# Extraer la primera línea del texto
cerrado_df_e_m_d['Fecha de Incidencia'] = cerrado_df_e_m_d['Fecha de Incidencia'].str.replace(r'^[^\d]*(\d.*)', r'\1', regex=True) # espacios entre str de mas 
cerrado_df_e_m_d['Fecha de Incidencia'] = cerrado_df_e_m_d['Fecha de Incidencia'].str.replace(r'(?i)\bhi\b', '', regex=True).str.strip()
cerrado_df_e_m_d['Fecha de Incidencia'] = cerrado_df_e_m_d['Fecha de Incidencia'].str.replace('-','/').str.strip()

# %%
cerrado_df_e_m_d['Fecha de Incidencia'] = np.where(cerrado_df_e_m_d['Fecha de Incidencia'].str.len() <= 5,
                                                cerrado_df_e_m_d['Fecha de Incidencia'] + ' ' + cerrado_df_e_m_d['Fecha de Reporte'].dt.date.astype(str).str.replace('-','/'),
                                                cerrado_df_e_m_d['Fecha de Incidencia'] )
cerrado_df_e_m_d['Fecha de Incidencia'] = cerrado_df_e_m_d['Fecha de Incidencia'].str.replace(r'\s+', ' ', regex=True).str.strip() # espacios de mas

cerrado_df_e_m_d['Fecha de Incidencia'] = cerrado_df_e_m_d['Fecha de Incidencia'].str.replace('*', '',).str.strip() # espacios de mas

# %%
cerrado_df_e_m_d['Fecha de Incidencia'] = cerrado_df_e_m_d['Fecha de Incidencia'].astype(str)

# %%
from datetime import datetime
import pandas as pd
from dateutil import parser

def convertir_con_referencia(row):
    fecha_str = row['Fecha de Incidencia']
    fecha_ref = row['Fecha de Reporte']
    
    # Normalización básica
    fecha_str = fecha_str.strip().replace('.', ':').replace(' : ', ' ')
    
    formatos_con_ano = [
        "%H:%M %Y/%m/%d",
        "%Y-%m-%d %H:%M",
        "%d/%m/%Y %H:%M",
        "%d/%m/%y %H:%M",
        "%d/%m/%Y"
    ]
    
    formatos_sin_ano = [
        "%d/%m %H:%M",
        "%d/%m : %H:%M",
        "%m-%d %H:%M",
        "%H:%M %d/%m",
        "%d/%m : %H.%M",
        "%H:%M %d/%m",
        "%H: %M %d/%m",
        "%d.%m %H:%M"
    ]
    
    # Intentar con formatos que incluyen año
    for fmt in formatos_con_ano:
        try:
            return datetime.strptime(fecha_str, fmt)
        except ValueError:
            continue
    
    # Intentar con formatos sin año y agregar el año de referencia
    for fmt in formatos_sin_ano:
        try:
            parcial = datetime.strptime(fecha_str, fmt)
            return parcial.replace(year=fecha_ref.year)
        except ValueError:
            continue
    
    # Último intento: usar dateutil.parser
    try:
        return parser.parse(fecha_str, default=fecha_ref)
    except Exception:
        return pd.NaT

# %%
cerrado_df_e_m_d['Fecha de Incidencia_Formated'] = cerrado_df_e_m_d.apply(convertir_con_referencia, axis=1)

# %%
cerrado_df_e_m_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 572 entries, 0 to 571
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   timestamp                     572 non-null    datetime64[ns]
#  1   sender                        572 non-null    object
#  2   message                       572 non-null    object
#  3   codigos_inc                   572 non-null    object
#  4   Encabezado                    572 non-null    object
#  5   Contenido                     572 non-null    object
#  6   Plano                         572 non-null    object
#  7   Tipo de Averia                572 non-null    object
#  8   Nodo                          572 non-null    object
#  9   Fecha de Llegada Completa     237 non-null    datetime64[ns]
#  10  Fecha de Incidencia           572 non-null    object
#  11  Fecha de Reporte              572 non-null    datetime64[ns]
#  12  Fecha de Incidencia_Formated  572 non-null    datetime64[ns]
# dtypes: datetime64[ns](4), object(9)
# memory usage: 58.2+ KB

# %% [markdown]
# ## Creo Tipo de Falla
# ### Cuando no hay tecnico es falsa averia

# %%
cerrado_df_e = cerrado_df_e_m_d
##Cambiar orden primero las fehcas luego el tipo de falla

# %%
cerrado_df_e.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 572 entries, 0 to 571
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   timestamp                     572 non-null    datetime64[ns]
#  1   sender                        572 non-null    object
#  2   message                       572 non-null    object
#  3   codigos_inc                   572 non-null    object
#  4   Encabezado                    572 non-null    object
#  5   Contenido                     572 non-null    object
#  6   Plano                         572 non-null    object
#  7   Tipo de Averia                572 non-null    object
#  8   Nodo                          572 non-null    object
#  9   Fecha de Llegada Completa     237 non-null    datetime64[ns]
#  10  Fecha de Incidencia           572 non-null    object
#  11  Fecha de Reporte              572 non-null    datetime64[ns]
#  12  Fecha de Incidencia_Formated  572 non-null    datetime64[ns]
# dtypes: datetime64[ns](4), object(9)
# memory usage: 58.2+ KB

# %%
cerrado_df_e['Tipo de falla'] = pd.NA

# %%
cerrado_df_e['Tipo de falla'] = np.where(
    (cerrado_df_e['Contenido'].str.count('\n') < 7)|(cerrado_df_e['Fecha de Incidencia'].isna()) ,
    'FALSA AVERIA',
    cerrado_df_e['Tipo de falla']
)

# %%
import numpy as np  # por completar todos los tipos de falla
#cerrado_df_e['Contenido'] = cerrado_df_e['Contenido'].str.lower()
palabras_categoria_A =  ['domicilios','clientes no cuentan con energia','fuente con normalidad','informa retorno de energia',
                         'corte de energía lado clientes','informa tener corte de energia en la zona','corte domiciliario','corte de energia lado cliente',
                        'retorna la energía comercial','clientes sin energía comercial','clientes sin energía comercial',
                         'corte de energia en la zona','NO TIENE ENERGIA ELECTRICA','corte de energia en la zona','corte de energía lado cliente','tecnico indica corte de energía',
                        'sin energía comercial','se repuso energía eléctrica','retorno de energía en la zona']
palabras_categoria_B = ['cambio','cable 500']
palabras_categoria_C = ['sin intervencion del pext','tecnico indica voltaje conforme','breaker en ON','térmica bajo'
                        ,'fuente trabajando con normalidad','se observa plano arriba','observa plano restablecido']
palabras_categoria_D = ['variación de voltaje lado clientes','cerrados en automatico']
palabras_categoria_E = ['ggee','GGEE','GG.EE','se instala GE']
palabras_categoria_F = ['nodo sin po','potencia óptica']
palabras_categoria_G = ['POR CORTE PROGRAMADO','CORTE PROGRAMDO','corte programado']
palabras_categoria_H = ['Amplificador']
palabras_categoria_I = ['TAP']


# Condiciones


condiciones = [
    cerrado_df_e['Contenido'].str.contains('|'.join(palabras_categoria_A), case=False, na=False),
    cerrado_df_e['Contenido'].str.contains('|'.join(palabras_categoria_B), case=False, na=False),
    cerrado_df_e['Contenido'].str.contains('|'.join(palabras_categoria_C), case=False, na=False),
    cerrado_df_e['Contenido'].str.contains('|'.join(palabras_categoria_D), case=False, na=False),
    cerrado_df_e['Contenido'].str.contains('|'.join(palabras_categoria_E), case=False, na=False),
    cerrado_df_e['Contenido'].str.contains('|'.join(palabras_categoria_F), case=False, na=False),
    cerrado_df_e['Contenido'].str.contains('|'.join(palabras_categoria_G), case=False, na=False),
    cerrado_df_e['Contenido'].str.contains('|'.join(palabras_categoria_H), case=False, na=False),
    cerrado_df_e['Contenido'].str.contains('|'.join(palabras_categoria_I), case=False, na=False)



]
# Resultados correspondientes
categorias = ['CORTE DE ENERGIA DOMICILIARIA', 'CABLE 500 AVERIADO','FALSA AVERIA','AUTONOMIA CONSUMIDA','CORTE DE ENERGIA COMERCIAL','CORTE DE FIBRA','CORTE PROGRAMADO','AMPLIFICADOR AVERIADO'
            ,'ELEMENTO PASIVO AVERIADO']

# Aplicar condiciones
cerrado_df_e['Tipo de falla'] = np.select(condiciones, categorias,default=cerrado_df_e['Tipo de falla'])
cerrado_df_e['Tipo de falla'] = cerrado_df_e['Tipo de falla'].str.replace('*','')

# %%
cerrado_df_e['Tipo de falla'] = np.where(cerrado_df_e['Contenido'].str.len() < 105,
                                       'FALSA AVERIA',
                                     cerrado_df_e['Tipo de falla'])

# %%
cerrado_df_e['Tipo de falla'] =  cerrado_df_e['Tipo de falla'].fillna('otro')

# %%
cerrado_df_e.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 572 entries, 0 to 571
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   timestamp                     572 non-null    datetime64[ns]
#  1   sender                        572 non-null    object
#  2   message                       572 non-null    object
#  3   codigos_inc                   572 non-null    object
#  4   Encabezado                    572 non-null    object
#  5   Contenido                     572 non-null    object
#  6   Plano                         572 non-null    object
#  7   Tipo de Averia                572 non-null    object
#  8   Nodo                          572 non-null    object
#  9   Fecha de Llegada Completa     237 non-null    datetime64[ns]
#  10  Fecha de Incidencia           572 non-null    object
#  11  Fecha de Reporte              572 non-null    datetime64[ns]
#  12  Fecha de Incidencia_Formated  572 non-null    datetime64[ns]
#  13  Tipo de falla                 572 non-null    object
# dtypes: datetime64[ns](4), object(10)
# memory usage: 62.7+ KB

# %%
cerrado_df_e[cerrado_df_e.codigos_inc == 'INC000009149326']
# Out:
#               timestamp           sender  \
# 109 2025-07-25 14:35:00  +51 914 748 998
#
#                                                message      codigos_inc  \
# 109  *Se actualiza averías (Incidencias y WOs)*\nNO...  INC000009149326
#
#                                             Encabezado  \
# 109  *INC000009149326 - CHI061 vcsChiclayo02 TOTAL*...
#
#                                              Contenido Plano Tipo de Averia  \
# 109  HI: 25/7/25 8:31\nTECNICO PEXT: *HENRY VIZLAO*...     -           OTRO
#
#        Nodo Fecha de Llegada Completa Fecha de Incidencia    Fecha de Reporte  \
# 109  CHI061       2025-07-25 09:12:00        25/7/25 8:31 2025-07-25 08:36:00
#
#     Fecha de Incidencia_Formated               Tipo de falla
# 109          2025-07-25 08:31:00  CORTE DE ENERGIA COMERCIAL

# %%
cerrado_df_e['Tipo de falla'].value_counts(dropna=False)
# Out:
# Tipo de falla
# FALSA AVERIA                     267
# CORTE DE ENERGIA DOMICILIARIA    107
# CORTE PROGRAMADO                  96
# CORTE DE ENERGIA COMERCIAL        52
# CORTE DE FIBRA                    16
# CABLE 500 AVERIADO                13
# ELEMENTO PASIVO AVERIADO          10
# otro                               5
# AUTONOMIA CONSUMIDA                5
# AMPLIFICADOR AVERIADO              1
# Name: count, dtype: int64

# %% [markdown]
# ### inspeccion de casos

# %%
for i in cerrado_df_e[cerrado_df_e['Tipo de falla'] == 'otro'].Contenido:
    print(i)
    print('-------------')
# Out:
# 23/07 HI: 21:20
# TÉCNICO PEXT: *IVAN URQUIZA*
# 21:40 EN PROGRAMACION
# 22:23 Supervisor Roberto Guerra indica mantener en monitoreo por ser zona peligrosa
# 23:00 EN MONITOREO POR ZONA PELIGROSA
# 00:00 – 05:00 EN MONITOREO POR ZONA PELIGROSA
# Plano levantando se informa a BOSF.
# 06:22 Se procede al *CIERRE* de averia.
# -------------
# 02/08 HI: 00:08
# TEC.PEXT: *HENRY VIZLAO*
# 00:30 EN PROGRAMACION
# *AFECTACION DE FO ANILLO 01*
# 00:46 Supervisor Danny Huamanchumo informa, mantener planos en monitoreo ya que pertenecen a zona peligrosa
# 01:00-06:00 PLANOS EN MONITOREO, ZONA PELIGROSA, SE ATENDERA DURANTE EL DIA
# 05:45 Tecnico en breve atendera
# 06:41 Tecnico en plano CHI065
# 06:45 Tecnico informa que dorsal se encuentra en zona realizando trabajos. CHI065
# 07:00-08:00 PEXT y personal de FO realizando trabajos en conjunto
# 10:00 plano CHI055 se verifica restablecido.
# 11:35 Se verifica en gestores planos UP solucion brindada por empalme de FO
# *CERRADO BOSF*
# -------------
# 02/08 HI: 00:08
# TEC.PEXT: *HENRY VIZLAO*
# 00:30 EN PROGRAMACION
# *AFECTACION DE FO ANILLO 01*
# 00:46 Supervisor Danny Huamanchumo informa, mantener planos en monitoreo ya que pertenecen a zona peligrosa
# 01:00-06:00 PLANOS EN MONITOREO, ZONA PELIGROSA, SE ATENDERA DURANTE EL DIA
# 05:45 Tecnico en breve atendera
# 06:41 Tecnico en plano CHI065
# 06:45 Tecnico informa que dorsal se encuentra en zona realizando trabajos. CHI065
# 07:00-08:00 PEXT y personal de FO realizando trabajos en conjunto
# 10:00 plano CHI055 se verifica restablecido.
# 11:35 Se verifica en gestores planos UP solucion brindada por empalme de FO
# *CERRADO BOSF*
# -------------
# 02/08 HI: 00:08
# TEC.PEXT: *HENRY VIZLAO*
# 00:30 EN PROGRAMACION
# *AFECTACION DE FO ANILLO 01*
# 00:46 Supervisor Danny Huamanchumo informa, mantener planos en monitoreo ya que pertenecen a zona peligrosa
# 01:00-06:00 PLANOS EN MONITOREO, ZONA PELIGROSA, SE ATENDERA DURANTE EL DIA
# 05:45 Tecnico en breve atendera
# 06:41 Tecnico en plano CHI065
# 06:45 Tecnico informa que dorsal se encuentra en zona realizando trabajos. CHI065
# 07:00-08:00 PEXT y personal de FO realizando trabajos en conjunto
# 10:00 plano CHI055 se verifica restablecido.
# 11:35 Se verifica en gestores planos UP solucion brindada por empalme de FO
# *CERRADO BOSF*
# -------------
# 17/08 HI: 11:50
# TEC.PEXT: *IVAN URQUIZA*
# EN PROGRAMACION
# 13:00 Tecnico camino al plano
# 13:15 Tecnico en plano, procede a revisar
# 13:20 Tecnico verifica niveles conformes en edificio Roma 430
# 13:32 Tecnico verifica niveles conformes en Jr Berlín 164, cliente indica servicio conforme
# 13:44 Tecnico verifica niveles conformes en La habana 258
# 13:48 BOSF informa que plano se mantiene parcial
# 13:50 Tecnico verifica voltaje conforme
# 14:14 Tecnico verifica niveles conformes en Berlin 452
# 14:16 Tecnico informa que direcciones CA. MARCABALITO 1610 y CA. BLAS DE OSTOLAZA 218 , no pertenecen al plano
# 14:26 Tecnico informa que cliente SERGIO LAZO ECHEVARRIA, migro de HFC a Fibra de Claro el dia de ayer.
# 14:30 En coordinacion con el BOSF se procede al cierra de la incidencia, plano tiene niveles conformes
# *CERRADO* VALIDA BOSF
# -------------

# %%
cerrado_df_e.drop(['message','Encabezado','Fecha de Incidencia'],axis=1,inplace=True) 
cerrado_df_e.rename(columns={'timestamp' : 'Fecha Fin de Trabajo','Contenido':'Detalle','Fecha de Incidencia_Formated':'Fecha de Incidencia',
                             'Fecha de Llegada Completa':'Fecha de Llegada'},inplace=True)

# %% [markdown]
# ## Agrego las filas al existente

# %%
cerrado_df_e.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 572 entries, 0 to 571
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Fecha Fin de Trabajo  572 non-null    datetime64[ns]
#  1   sender                572 non-null    object
#  2   codigos_inc           572 non-null    object
#  3   Detalle               572 non-null    object
#  4   Plano                 572 non-null    object
#  5   Tipo de Averia        572 non-null    object
#  6   Nodo                  572 non-null    object
#  7   Fecha de Llegada      237 non-null    datetime64[ns]
#  8   Fecha de Reporte      572 non-null    datetime64[ns]
#  9   Fecha de Incidencia   572 non-null    datetime64[ns]
#  10  Tipo de falla         572 non-null    object
# dtypes: datetime64[ns](4), object(7)
# memory usage: 49.3+ KB

# %%
def proces_old_data(df_old,df_actual):
    if any(df_old):
        set_a = set(cerrado_df_e.codigos_inc.tolist())
        set_b = set(df_old.codigos_inc.tolist())
        elementos_comunes = set_a.intersection(set_b)
        if any(elementos_comunes):
            print("Incidencias duplicadas")
            df_old = df_old[~df_old.codigos_inc.isin(elementos_comunes)]
        else:
            print("sin incidencias duplicadas,agrego")
            pass 
        df_total = pd.concat([df_old,cerrado_df_e],axis=0,ignore_index = True)
    else: 
        df_total = df_actual
    return df_total

# %%
df_total = cerrado_df_e.copy()

# %% [markdown]
# # Transformacion de Data final

# %%
df_total['Lugar'] = df_total.Nodo.str.replace(r'^(vcs|olt|cmts)', '', regex=True)
df_total.Lugar = df_total.Lugar.str.replace('*','')
df_total.Lugar  = df_total.Lugar.str.replace(r'\d+$', '', regex=True)

# %%
df_total['Lugar'] = np.where(df_total['Lugar'].str.contains('chiclayo', case=False), 'Chiclayo',
                    np.where(df_total['Lugar'].str.contains('trujill', case=False), 'Trujillo',
                    np.where(df_total['Lugar'].str.contains('cajamarca', case=False), 'Cajamarca', 
                    np.where(df_total['Lugar'].str.contains('chimbote', case=False), 'Chimbote',
                    np.where(df_total['Lugar'].str.contains('sullana', case=False), 'Sullana',df_total['Lugar'])))))

# %%
df_total.Lugar  = df_total.Lugar.str.replace('CHI', 'Chiclayo')
df_total.Lugar  = df_total.Lugar.str.replace('TRLE', 'Trujillo')

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 572 entries, 0 to 571
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Fecha Fin de Trabajo  572 non-null    datetime64[ns]
#  1   sender                572 non-null    object
#  2   codigos_inc           572 non-null    object
#  3   Detalle               572 non-null    object
#  4   Plano                 572 non-null    object
#  5   Tipo de Averia        572 non-null    object
#  6   Nodo                  572 non-null    object
#  7   Fecha de Llegada      237 non-null    datetime64[ns]
#  8   Fecha de Reporte      572 non-null    datetime64[ns]
#  9   Fecha de Incidencia   572 non-null    datetime64[ns]
#  10  Tipo de falla         572 non-null    object
#  11  Lugar                 572 non-null    object
# dtypes: datetime64[ns](4), object(8)
# memory usage: 53.8+ KB

# %%
df_total.Lugar.value_counts()
# Out:
# Lugar
# Trujillo     237
# Chiclayo     151
# Piura         62
# Cajamarca     61
# Chimbote      54
# Sullana        7
# Name: count, dtype: int64

# %% [markdown]
# ## Calculo de columnas calculadas

# %%
df_total['Tiempo de atencion'] = df_total['Fecha Fin de Trabajo'] - df_total['Fecha de Llegada']

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 572 entries, 0 to 571
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Fecha Fin de Trabajo  572 non-null    datetime64[ns]
#  1   sender                572 non-null    object
#  2   codigos_inc           572 non-null    object
#  3   Detalle               572 non-null    object
#  4   Plano                 572 non-null    object
#  5   Tipo de Averia        572 non-null    object
#  6   Nodo                  572 non-null    object
#  7   Fecha de Llegada      237 non-null    datetime64[ns]
#  8   Fecha de Reporte      572 non-null    datetime64[ns]
#  9   Fecha de Incidencia   572 non-null    datetime64[ns]
#  10  Tipo de falla         572 non-null    object
#  11  Lugar                 572 non-null    object
#  12  Tiempo de atencion    237 non-null    timedelta64[ns]
# dtypes: datetime64[ns](4), object(8), timedelta64[ns](1)
# memory usage: 58.2+ KB

# %%
df_total = df_total[['sender','codigos_inc','Plano','Lugar','Tipo de Averia','Tipo de falla','Nodo','Fecha de Incidencia','Fecha de Llegada','Tiempo de atencion',
                                             'Fecha Fin de Trabajo','Fecha de Reporte','Detalle']]

# %%
try: 
    #df_old = pd.read_excel(r'D:\DATA\Test_watchdog\Resultados\test_v0.xlsx')
    df_old = pd.read_excel(r'Resultados\Averias-HFC.xlsx')
    
except:
    print("no existe archivo creado,creo uno")
    df_old = pd.DataFrame()
df_total = proces_old_data(df_old,df_total)
# Out:
# no existe archivo creado,creo uno

# %% [markdown]
# # Cargo el resultado

# %%
df_total.to_excel(r'Resultados\Averias-HFC.xlsx',index=False)
#df_total.to_excel(r'D:\DATA\Test_watchdog\Resultados\test_v0.xlsx',index=False)

# %%
#df_total.to_csv(r'D:\DATA\Test_watchdog\Resultados\test_v0.xlsx',index=False)
